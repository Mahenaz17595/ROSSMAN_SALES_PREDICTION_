# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahenaz17595/ROSSMAN_SALES_PREDICTION_FINAL/blob/master/Copy_of_ROSSMAN_SALES_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# loading packages
# basic + dates 
import numpy as np
import pandas as pd
from pandas import datetime

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns # advanced vizs
# %matplotlib inline

# statistics
from statsmodels.distributions.empirical_distribution import ECDF

# time series analysis
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from fbprophet import Prophet
# machine learning: XGB
import xgboost as xgb
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from xgboost.sklearn import XGBRegressor # wrapper

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# importing train data to learn
train = pd.read_csv('/content/drive/My Drive/Project_3/Dataset/train.csv', 
                    parse_dates = True, low_memory = False, index_col = 'Date')

# additional store data
store = pd.read_csv('/content/drive/My Drive/Project_3/Dataset/store.csv', 
                    low_memory = False)
# time series as indexes
train.index
# Out:
# DatetimeIndex(['2015-07-31', '2015-07-31', '2015-07-31', '2015-07-31',
#                '2015-07-31', '2015-07-31', '2015-07-31', '2015-07-31',
#                '2015-07-31', '2015-07-31',
#                ...
#                '2013-01-01', '2013-01-01', '2013-01-01', '2013-01-01',
#                '2013-01-01', '2013-01-01', '2013-01-01', '2013-01-01',
#                '2013-01-01', '2013-01-01'],
#               dtype='datetime64[ns]', name='Date', length=1017209, freq=None)

# %% [markdown]
# **Exploratory Data Analysis**
#
# In this first section we go through the train and store data, handle missing values and create new features for further analysis.

# %%
print("In total: ", train.shape)
train.head(5).append(train.tail(5))
# Out:
# In total:  (1017209, 8)
#             Store  DayOfWeek  Sales  ...  Promo  StateHoliday  SchoolHoliday
# Date                                 ...
# 2015-07-31      1          5   5263  ...      1             0              1
# 2015-07-31      2          5   6064  ...      1             0              1
# 2015-07-31      3          5   8314  ...      1             0              1
# 2015-07-31      4          5  13995  ...      1             0              1
# 2015-07-31      5          5   4822  ...      1             0              1
# 2013-01-01   1111          2      0  ...      0             a              1
# 2013-01-01   1112          2      0  ...      0             a              1
# 2013-01-01   1113          2      0  ...      0             a              1
# 2013-01-01   1114          2      0  ...      0             a              1
# 2013-01-01   1115          2      0  ...      0             a              1
#
# [10 rows x 8 columns]

# %% [markdown]
# **Short description:**
#
# * Sales: the turnover for any given day (target variable).
# * Customers: the number of customers on a given day.
# * Open: an indicator for whether the store was open: 0 = closed, 1 = open.
# * Promo: indicates whether a store is running a promo on that day.
# * StateHoliday: indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays.
# * SchoolHoliday: indicates if the (Store, Date) was affected by the closure of public schools.
#
# We are dealing with time series data so it will probably serve us to extract dates for further analysis. We also have two likely correlated vaiables in the dataset, which can be combined into a new feature.

# %%
# data extraction
train['Year'] = train.index.year
train['Month'] = train.index.month
train['Day'] = train.index.day
train['WeekOfYear'] = train.index.weekofyear

# adding new variable
train['SalePerCustomer'] = train['Sales']/train['Customers']
train['SalePerCustomer'].describe()
# Out:
# count    844340.000000
# mean          9.493619
# std           2.197494
# min           0.000000
# 25%           7.895563
# 50%           9.250000
# 75%          10.899729
# max          64.957854
# Name: SalePerCustomer, dtype: float64

# %% [markdown]
# On average customers spend about 9.50$ per day. Though there are days with Sales equal to zero.

# %% [markdown]
# **ECDF: empirical cumulative distribution function**
#
# To get the first impression about continious variables in the data we can plot ECDF.

# %%
sns.set(style = "ticks")# to format into seaborn 
c = '#386B7F' # basic color for plots
plt.figure(figsize = (12, 6))

plt.subplot(311)
cdf = ECDF(train['Sales'])
plt.plot(cdf.x, cdf.y, label = "statmodels", color = c);
plt.xlabel('Sales'); plt.ylabel('ECDF');

# plot second ECDF  
plt.subplot(312)
cdf = ECDF(train['Customers'])
plt.plot(cdf.x, cdf.y, label = "statmodels", color = c);
plt.xlabel('Customers');

# plot second ECDF  
plt.subplot(313)
cdf = ECDF(train['SalePerCustomer'])
plt.plot(cdf.x, cdf.y, label = "statmodels", color = c);
plt.xlabel('Sale per Customer');

# %% [markdown]
# About 20% of data has zero amount of sales/customers that we need to deal with and almost 80% of time daily amount of sales was less than 1000. So what about zero sales, is it only due to the fact that the store is closed?

# %% [markdown]
# **Missing values Closed stores and zero sales stores**

# %%
# closed stores
train[(train.Open == 0) & (train.Sales == 0)].head()
# Out:
#             Store  DayOfWeek  Sales  ...  Day  WeekOfYear  SalePerCustomer
# Date                                 ...
# 2015-07-31    292          5      0  ...   31          31              NaN
# 2015-07-31    876          5      0  ...   31          31              NaN
# 2015-07-30    292          4      0  ...   30          31              NaN
# 2015-07-30    876          4      0  ...   30          31              NaN
# 2015-07-29    292          3      0  ...   29          31              NaN
#
# [5 rows x 13 columns]

# %%
# opened stores with zero sales
zero_sales = train[(train.Open != 0) & (train.Sales == 0)]
print("In total: ", zero_sales.shape)
zero_sales.head(5)
# Out:
# In total:  (54, 13)
#             Store  DayOfWeek  Sales  ...  Day  WeekOfYear  SalePerCustomer
# Date                                 ...
# 2015-05-15    971          5      0  ...   15          20              NaN
# 2015-03-26    674          4      0  ...   26          13              NaN
# 2015-02-05    699          4      0  ...    5           6              NaN
# 2014-10-01    708          3      0  ...    1          40              NaN
# 2014-09-22    357          1      0  ...   22          39              NaN
#
# [5 rows x 13 columns]

# %%
print("Closed stores and days which didn't have any sales won't be counted into the forecasts.")
train = train[(train["Open"] != 0) & (train['Sales'] != 0)]

print("In total: ", train.shape)
# Out:
# Closed stores and days which didn't have any sales won't be counted into the forecasts.
# In total:  (844338, 13)

# %%
# additional information about the stores
store.head()
# Out:
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             NaN              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             NaN              NaN
# 4      5         a  ...             NaN              NaN
#
# [5 rows x 10 columns]

# %% [markdown]
# * Store: a unique Id for each store
# * StoreType: differentiates between 4 different store models: a, b, c, d
# * Assortment: describes an assortment level: a = basic, b = extra, c = extended
# * CompetitionDistance: distance in meters to the nearest competitor store
# * CompetitionOpenSince[Month/Year]: gives the approximate year and month of the time the nearest competitor was opened
# * Promo2: Promo2 is a continuing a promotion for some stores: 0 = store is not participating, 1 = store is participating
# * Promo2Since[Year/Week]: describes the year and calendar week when the store started participating in Promo2
# * PromoInterval: describes the consecutive intervals Promo2 is started, naming the months the promotion is started. E.g. "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store

# %%
# missing values?
store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %% [markdown]
# We have few variables with missing values that we need to deal with. Let's start with the CompetitionDistance.

# %%
# missing values in CompetitionDistance
store[pd.isnull(store.CompetitionDistance)]
# Out:
#      Store StoreType  ... Promo2SinceYear    PromoInterval
# 290    291         d  ...             NaN              NaN
# 621    622         a  ...             NaN              NaN
# 878    879         d  ...          2013.0  Feb,May,Aug,Nov
#
# [3 rows x 10 columns]

# %% [markdown]
# Replace NaN with the median values (which is twice less that the average).

# %%
# fill NaN with a median value (skewed distribuion)
store['CompetitionDistance'].fillna(store['CompetitionDistance'].median(), inplace = True)

# %% [markdown]
# Continuing further with missing data. What about Promo2SinceWeek? May it be that we observe unsusual data points?

# %%
# no promo = no information about the promo?
_ = store[pd.isnull(store.Promo2SinceWeek)]
_[_.Promo2 != 0].shape
# Out:
# (0, 10)

# %% [markdown]
# No, if there's no Promo2 then there's no information about it. We can replace these values by zeros. The same goes for the variables deducted from the competition, CompetitionOpenSinceMonth and CompetitionOpenSinceYear.

# %%
# replace NA's by 0
store.fillna(0, inplace = True)

# %%
print("Joining train set with an additional store information.")

# by specifying inner join we make sure that only those observations 
# that are present in both train and store sets are merged together
train_store = pd.merge(train, store, how = 'inner', on = 'Store')

print("In total: ", train_store.shape)
train_store.head()
# Out:
# Joining train set with an additional store information.
# In total:  (844338, 22)
#    Store  DayOfWeek  Sales  ...  Promo2SinceWeek  Promo2SinceYear  PromoInterval
# 0      1          5   5263  ...              0.0              0.0              0
# 1      1          4   5020  ...              0.0              0.0              0
# 2      1          3   4782  ...              0.0              0.0              0
# 3      1          2   5011  ...              0.0              0.0              0
# 4      1          1   6102  ...              0.0              0.0              0
#
# [5 rows x 22 columns]

# %% [markdown]
# Store types
# In this section we will closely look at different levels of StoreType and how the main metric Sales is distributed among them.

# %%
train_store.groupby('StoreType')['Sales'].describe()
# Out:
#               count          mean          std  ...     50%       75%      max
# StoreType                                       ...
# a          457042.0   6925.697986  3277.351589  ...  6285.0   8406.00  41551.0
# b           15560.0  10233.380141  5155.729868  ...  9130.0  13184.25  38722.0
# c          112968.0   6933.126425  2896.958579  ...  6408.0   8349.25  31448.0
# d          258768.0   6822.300064  2556.401455  ...  6395.0   8123.25  38037.0
#
# [4 rows x 8 columns]

# %% [markdown]
# StoreType B has the highest average of Sales among all others, however we have much less data for it. So let's print an overall sum of Sales and Customers to see which StoreType is the most selling and crowded one:

# %%
train_store.groupby('StoreType')['Customers', 'Sales'].sum()
# Out:
#            Customers       Sales
# StoreType
# a          363541431  3165334859
# b           31465616   159231395
# c           92129705   783221426
# d          156904995  1765392943

# %% [markdown]
# Clearly stores of type A. StoreType D goes on the second place in both Sales and Customers.

# %%
# sales trends
sns.factorplot(data = train_store, x = 'Month', y = "Sales", 
               col = 'StoreType', # per store type in cols
               palette = 'plasma',
               hue = 'StoreType',
               row = 'Promo', # per promo in the store in rows
               color = c)

# %%
# sales trends
sns.factorplot(data = train_store, x = 'Month', y = "Customers", 
               col = 'StoreType', # per store type in cols
               palette = 'plasma',
               hue = 'StoreType',
               row = 'Promo', # per promo in the store in rows
               color = c)

# %% [markdown]
# All store types follow the same trend but at different scales depending on the presence of the (first) promotion Promo and StoreType itself (case for B).
#
# Already at this point, we can see that Sales escalate towards Christmas holidays.

# %%
# sale per customer trends
sns.factorplot(data = train_store, x = 'Month', y = "SalePerCustomer", 
               col = 'StoreType', # per store type in cols
               palette = 'plasma',
               hue = 'StoreType',
               row = 'Promo', # per promo in the store in rows
               color = c)

# %% [markdown]
#  Eventhough the plots above showed StoreType B as the most selling and performant one, in reality it is not true. The highest SalePerCustomer amount is observed at the StoreType D, about 12 dollar with promo and 10 dollar without. As for StoreType A and C it is about 9$.
#
# Low SalePerCustomer amount for StoreType B describes its Buyer Cart: there are a lot of people who shop essentially for "small" things (or in a little quantity). Plus we saw that overall this StoreType generated the least amount of sales and customers over the period.

# %%
# customers
sns.factorplot(data = train_store, x = 'Month', y = "Sales", 
               col = 'DayOfWeek', # per store type in cols
               palette = 'plasma',
               hue = 'StoreType',
               row = 'StoreType', # per store type in rows
               color = c)

# %% [markdown]
# We see that stores of StoreType C are all closed on Sundays, whereas others are most of the time opened. Interestingly enough, stores of StoreType D are closed on Sundays only from October to December.
#
# By the way what are the stores which are opened on Sundays?

# %%
# stores which are opened on Sundays
train_store[(train_store.Open == 1) & (train_store.DayOfWeek == 7)]['Store'].unique()
# Out:
# array([  85,  122,  209,  259,  262,  274,  299,  310,  335,  353,  423,
#         433,  453,  494,  512,  524,  530,  562,  578,  676,  682,  732,
#         733,  769,  863,  867,  877,  931,  948, 1045, 1081, 1097, 1099])

# %% [markdown]
# To complete our preliminary data analysis, we can add variables describing the period of time during which competition and promotion were opened:

# %%
# competition open time (in months)
train_store['CompetitionOpen'] = 12 * (train_store.Year - train_store.CompetitionOpenSinceYear) + \
        (train_store.Month - train_store.CompetitionOpenSinceMonth)
    
# Promo open time
train_store['PromoOpen'] = 12 * (train_store.Year - train_store.Promo2SinceYear) + \
        (train_store.WeekOfYear - train_store.Promo2SinceWeek) / 4.0

# replace NA's by 0
train_store.fillna(0, inplace = True)

# average PromoOpen time and CompetitionOpen time per store type
train_store.loc[:, ['StoreType', 'Sales', 'Customers', 'PromoOpen', 'CompetitionOpen']].groupby('StoreType').mean()
# Out:
#                   Sales    Customers     PromoOpen  CompetitionOpen
# StoreType
# a           6925.697986   795.422370  12918.492198      7115.514452
# b          10233.380141  2022.211825  17199.328069     11364.495244
# c           6933.126425   815.538073  12158.636107      6745.418694
# d           6822.300064   606.353935  10421.916846      9028.526526

# %% [markdown]
# The most selling and crowded StoreType A doesn't appear to be the one the most exposed to competitors. Instead it's a StoreType B, which also has the longest running period of promotion.

# %% [markdown]
# #Correlational Analysis
# We are finished with adding new variables to the data, so now we can check the overall correlations by plotting the seaborn heatmap:

# %%
# Compute the correlation matrix 
# exclude 'Open' variable
corr_all = train_store.drop('Open', axis = 1).corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr_all, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize = (11, 9))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_all, mask = mask,
            square = True, linewidths = .5, ax = ax, cmap = "BuPu")      
plt.show()

# %% [markdown]
# As mentioned before, we have a strong positive correlation between the amount of Sales and Customers of a store. We can also observe a positive correlation between the fact that the store had a running promotion (Promo equal to 1) and amount of Customers.
#
# However, as soon as the store continues a consecutive promotion (Promo2 equal to 1) the number of Customers and Sales seems to stay the same or even decrease, which is described by the pale negative correlation on the heatmap. The same negative correlation is observed between the presence of the promotion in the store and the day of a week.

# %%
# sale per customer trends
sns.factorplot(data = train_store, x = 'DayOfWeek', y = "Sales", 
               col = 'Promo', 
               row = 'Promo2',
               hue = 'Promo2',
               palette = 'RdPu')

# %% [markdown]
# **Conclusion of EDA**
#
# The most selling and crowded StoreType is A.
# The best "Sale per Customer" StoreType D indicates to the higher Buyer Cart.

# %% [markdown]
# #Time-Series Analysis per Store Type
# What makes a time series different from a regular regression problem?
#
# It is time dependent. The basic assumption of a linear regression that the observations are independent doesn’t hold in this case.
# Along with an increasing or decreasing trend, most time series have some form of seasonality trends, i.e. variations specific to a particular time frame.
#
# We are able to develop a seasonal ARIMA (Autoregression Integrated Moving Average) model and then later the forecasts using Prophet methodology.

# %% [markdown]
# Seasonality
# We take four stores from store types to represent their group:
#
# Store number 2 for StoreType A
# Store number 85 for StoreType B,
# Store number 1 for StoreType C
# Store number 13 for StoreType D.
# It also makes sense to downsample the data from days to weeks using the resample method to see the present trends more clearly.

# %%
# preparation: input should be float type
train['Sales'] = train['Sales'] * 1.0

# store types
sales_a = train[train.Store == 2]['Sales']
sales_b = train[train.Store == 85]['Sales'].sort_index(ascending = True) # solve the reverse order
sales_c = train[train.Store == 1]['Sales']
sales_d = train[train.Store == 13]['Sales']

f, (ax1, ax2, ax3, ax4) = plt.subplots(4, figsize = (12, 13))

# store types
sales_a.resample('W').sum().plot(color = c, ax = ax1)
sales_b.resample('W').sum().plot(color = c, ax = ax2)
sales_c.resample('W').sum().plot(color = c, ax = ax3)
sales_d.resample('W').sum().plot(color = c, ax = ax4)

# %% [markdown]
# Retail sales for StoreType A and C tend to peak for the Christmas season and then decline after the holidays. We might have seen the same trend for StoreType D (at the bottom) but there is no information from July 2014 to January 2015 about these stores as they were closed.

# %% [markdown]
# Yearly trend
# The next thing to check the presence of a trend in series.

# %%
f, (ax1, ax2, ax3, ax4) = plt.subplots(4, figsize = (12, 13))

# monthly
decomposition_a = seasonal_decompose(sales_a, model = 'additive', freq = 365)
decomposition_a.trend.plot(color = c, ax = ax1)

decomposition_b = seasonal_decompose(sales_b, model = 'additive', freq = 365)
decomposition_b.trend.plot(color = c, ax = ax2)

decomposition_c = seasonal_decompose(sales_c, model = 'additive', freq = 365)
decomposition_c.trend.plot(color = c, ax = ax3)

decomposition_d = seasonal_decompose(sales_d, model = 'additive', freq = 365)
decomposition_d.trend.plot(color = c, ax = ax4)

# %% [markdown]
# Overall sales seems to increase, however not for the StoreType C (a third from the top). Eventhough the StoreType A is the most selling store type in the dataset, it seems that it cab follow the same decresing trajectory as StoreType C did.

# %%
# figure for subplots
plt.figure(figsize = (12, 8))

# acf and pacf for A
plt.subplot(421); plot_acf(sales_a, lags = 50, ax = plt.gca(), color = c)
plt.subplot(422); plot_pacf(sales_a, lags = 50, ax = plt.gca(), color = c)

# acf and pacf for B
plt.subplot(423); plot_acf(sales_b, lags = 50, ax = plt.gca(), color = c)
plt.subplot(424); plot_pacf(sales_b, lags = 50, ax = plt.gca(), color = c)

# acf and pacf for C
plt.subplot(425); plot_acf(sales_c, lags = 50, ax = plt.gca(), color = c)
plt.subplot(426); plot_pacf(sales_c, lags = 50, ax = plt.gca(), color = c)

# acf and pacf for D
plt.subplot(427); plot_acf(sales_d, lags = 50, ax = plt.gca(), color = c)
plt.subplot(428); plot_pacf(sales_d, lags = 50, ax = plt.gca(), color = c)

plt.show()

# %% [markdown]
# We can read these plots horizontally. Each horizontal pair is for one 'StoreType', from A to D. In general, those plots are showing the correlation of the series with itself, lagged by x time units correlation of the series with itself, lagged by x time units.
#
# There is at two things common for each pair of plots: non randomnes of the time series and high lag-1 (which will probably need a higher order of differencing d/D).
#
# Type A and type B: Both types show seasonalities at certain lags. For type A, it is each 12th observation with positives spikes at the 12 (s) and 24(2s) lags and so on. For type B it's a weekly trend with positives spikes at the 7(s), 14(2s), 21(3s) and 28(4s) lags.
# Type C and type D: Plots of these two types are more complex. It seems like each observation is coorrelated to its adjacent observations

# %% [markdown]
# Time Series Analysis and Forecasting with Prophet
# Forecasting for the next 6 weeks for the first store

# %%
# importing data
df = pd.read_csv('/content/drive/My Drive/Project_3/Dataset/train.csv',  
                    low_memory = False)

# remove closed stores and those with no sales
df = df[(df["Open"] != 0) & (df['Sales'] != 0)]

# sales for the store number 1 (StoreType C)
sales = df[df.Store == 1].loc[:, ['Date', 'Sales']]

# reverse to the order: from 2013 to 2015
sales = sales.sort_index(ascending = False)

# to datetime64
sales['Date'] = pd.DatetimeIndex(sales['Date'])
sales.dtypes
# Out:
# Date     datetime64[ns]
# Sales             int64
# dtype: object

# %%
# from the prophet documentation every variables should have specific names
sales = sales.rename(columns = {'Date': 'ds',
                                'Sales': 'y'})
sales.head()
# Out:
#                 ds     y
# 1014980 2013-01-02  5530
# 1013865 2013-01-03  4327
# 1012750 2013-01-04  4486
# 1011635 2013-01-05  4997
# 1009405 2013-01-07  7176

# %%
# plot daily sales
ax = sales.set_index('ds').plot(figsize = (12, 4), color = c)
ax.set_ylabel('Daily Number of Sales')
ax.set_xlabel('Date')
plt.show()

# %% [markdown]
# Modeling Holidays
# Prophet also allows to model for holidays, and that's what we do here.
#
# The StateHoliday variable in the dataset indicates a state holiday, at which all stores are normally closed. There are also school holidays in the dataset at which ceratin stores are also closing their doors.

# %%
# create holidays dataframe
state_dates = df[(df.StateHoliday == 'a') | (df.StateHoliday == 'b') & (df.StateHoliday == 'c')].loc[:, 'Date'].values
school_dates = df[df.SchoolHoliday == 1].loc[:, 'Date'].values

state = pd.DataFrame({'holiday': 'state_holiday',
                      'ds': pd.to_datetime(state_dates)})
school = pd.DataFrame({'holiday': 'school_holiday',
                      'ds': pd.to_datetime(school_dates)})

holidays = pd.concat((state, school))      
holidays.head()
# Out:
#          holiday         ds
# 0  state_holiday 2015-06-04
# 1  state_holiday 2015-06-04
# 2  state_holiday 2015-06-04
# 3  state_holiday 2015-06-04
# 4  state_holiday 2015-06-04

# %%
# set the uncertainty interval to 95% (the Prophet default is 80%)
my_model = Prophet(interval_width = 0.95, 
                   holidays = holidays)
my_model.fit(sales)

# dataframe that extends into future 6 weeks 
future_dates = my_model.make_future_dataframe(periods = 6*7)

print("First week to forecast.")
future_dates.tail(7)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# First week to forecast.
#             ds
# 816 2015-09-05
# 817 2015-09-06
# 818 2015-09-07
# 819 2015-09-08
# 820 2015-09-09
# 821 2015-09-10
# 822 2015-09-11

# %%
# predictions
forecast = my_model.predict(future_dates)

# preditions for last week
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)
# Out:
#             ds         yhat   yhat_lower   yhat_upper
# 816 2015-09-05  4092.135712  2433.851171  5816.133843
# 817 2015-09-06  4087.032784  2503.783753  5614.018715
# 818 2015-09-07  4161.813517  2657.549781  5860.868059
# 819 2015-09-08  3664.142168  1957.930727  5321.360697
# 820 2015-09-09  3550.915165  1932.349008  5223.365258
# 821 2015-09-10  3462.435748  1805.081138  5053.642761
# 822 2015-09-11  3717.122489  2130.261040  5314.408825

# %% [markdown]
# The forecast object here is a new dataframe that includes a column yhat with the forecast, as well as columns for components and uncertainty intervals.

# %%
fc = forecast[['ds', 'yhat']].rename(columns = {'Date': 'ds', 'Forecast': 'yhat'})

# %% [markdown]
# Prophet plots the observed values of our time series (the black dots), the forecasted values (blue line) and the uncertainty intervals of our forecasts (the blue shaded regions).

# %%
# visualizing predicions
my_model.plot(forecast);

# %% [markdown]
# As we see Prophet catches the trends and most of the time gets future values right.
#
# One other particularly strong feature of Prophet is its ability to return the components of our forecasts. This can help reveal how daily, weekly and yearly patterns of the time series plus manyally included holidayes contribute to the overall forecasted values:

# %%
my_model.plot_components(forecast);

# %% [markdown]
# The first plot shows that the monthly sales of store number 1 has been linearly decreasing over time and the second shows the holiays gaps included in the model. The third plot highlights the fact that the weekly volume of last week sales peaks towards the Monday of the next week, while the forth plot shows that the most busy season occurs during the Christmas holidays.

# %%
# to predict to
test = pd.read_csv('/content/drive/My Drive/Project_3/Dataset/test.csv', 
                    parse_dates = True, low_memory = False, index_col = 'Date')
test.head()
# Out:
#             Id  Store  DayOfWeek  Open  Promo StateHoliday  SchoolHoliday
# Date
# 2015-09-17   1      1          4   1.0      1            0              0
# 2015-09-17   2      3          4   1.0      1            0              0
# 2015-09-17   3      7          4   1.0      1            0              0
# 2015-09-17   4      8          4   1.0      1            0              0
# 2015-09-17   5      9          4   1.0      1            0              0

# %% [markdown]
# The Id variable represents a (Store, Date) duple within the test set.

# %%
# test: missing values?
test.isnull().sum()
# Out:
# Id                0
# Store             0
# DayOfWeek         0
# Open             11
# Promo             0
# StateHoliday      0
# SchoolHoliday     0
# dtype: int64

# %%
test[pd.isnull(test.Open)]
# Out:
#                Id  Store  DayOfWeek  Open  Promo StateHoliday  SchoolHoliday
# Date
# 2015-09-17    480    622          4   NaN      1            0              0
# 2015-09-16   1336    622          3   NaN      1            0              0
# 2015-09-15   2192    622          2   NaN      1            0              0
# 2015-09-14   3048    622          1   NaN      1            0              0
# 2015-09-12   4760    622          6   NaN      0            0              0
# 2015-09-11   5616    622          5   NaN      0            0              0
# 2015-09-10   6472    622          4   NaN      0            0              0
# 2015-09-09   7328    622          3   NaN      0            0              0
# 2015-09-08   8184    622          2   NaN      0            0              0
# 2015-09-07   9040    622          1   NaN      0            0              0
# 2015-09-05  10752    622          6   NaN      0            0              0

# %% [markdown]
# We see that these stores should be normally opened. Let's assume that they are then.

# %%
# replace NA's in Open variable by 1 
test.fillna(1, inplace = True)

# %% [markdown]
# Data Encoding
# XGBoost doesn't support anything else than numbers. So prior to modeling we need to encode certain factor variables into numerical plus extract dates as we did before for the train set.

# %%
# data extraction
test['Year'] = test.index.year
test['Month'] = test.index.month
test['Day'] = test.index.day
test['WeekOfYear'] = test.index.weekofyear

# to numerical
mappings = {'0':0, 'a':1, 'b':2, 'c':3, 'd':4}
test.StateHoliday.replace(mappings, inplace = True)

train_store.Assortment.replace(mappings, inplace = True)
train_store.StoreType.replace(mappings, inplace = True)
train_store.StateHoliday.replace(mappings, inplace = True)
train_store.drop('PromoInterval', axis = 1, inplace = True)

store.StoreType.replace(mappings, inplace = True)
store.Assortment.replace(mappings, inplace = True)
store.drop('PromoInterval', axis = 1, inplace = True)

# %% [markdown]
# Returning back to the train_store data:

# %%
# take a look on the train and store again
train_store.head()
# Out:
#    Store  DayOfWeek  Sales  ...  Promo2SinceYear  CompetitionOpen  PromoOpen
# 0      1          5   5263  ...              0.0             82.0   24187.75
# 1      1          4   5020  ...              0.0             82.0   24187.75
# 2      1          3   4782  ...              0.0             82.0   24187.75
# 3      1          2   5011  ...              0.0             82.0   24187.75
# 4      1          1   6102  ...              0.0             82.0   24187.75
#
# [5 rows x 23 columns]

# %% [markdown]
# Let's merge test and store data too:

# %%
print("Joining test set with an additional store information.")
test_store = pd.merge(test, store, how = 'inner', on = 'Store')

test_store['CompetitionOpen'] = 12 * (test_store.Year - test_store.CompetitionOpenSinceYear) + (test_store.Month - test_store.CompetitionOpenSinceMonth)
test_store['PromoOpen'] = 12 * (test_store.Year - test_store.Promo2SinceYear) + (test_store.WeekOfYear - test_store.Promo2SinceWeek) / 4.0

print("In total: ", test_store.shape)
test_store.head()
# Out:
# Joining test set with an additional store information.
# In total:  (41088, 21)
#      Id  Store  DayOfWeek  ...  Promo2SinceYear  CompetitionOpen  PromoOpen
# 0     1      1          4  ...              0.0             84.0   24189.50
# 1   857      1          3  ...              0.0             84.0   24189.50
# 2  1713      1          2  ...              0.0             84.0   24189.50
# 3  2569      1          1  ...              0.0             84.0   24189.50
# 4  3425      1          7  ...              0.0             84.0   24189.25
#
# [5 rows x 21 columns]

# %%
# split into training and evaluation sets
# excluding Sales and Id columns
predictors = [x for x in train_store.columns if x not in ['Customers', 'Sales', 'SalePerCustomer']]
y = np.log(train_store.Sales) # log transformation of Sales
X = train_store

# split the data into train/test set
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.3, # 30% for the evaluation set
                                                    random_state = 42)

# %%
# predictors
X.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Day', 'WeekOfYear',
#        'SalePerCustomer', 'StoreType', 'Assortment', 'CompetitionDistance',
#        'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
#        'Promo2SinceWeek', 'Promo2SinceYear', 'CompetitionOpen', 'PromoOpen'],
#       dtype='object')

# %%
# evaluation metric: rmspe
# Root Mean Square Percentage Error

def rmspe(y, yhat):
    return np.sqrt(np.mean((yhat / y-1) ** 2))

def rmspe_xg(yhat, y):
    y = np.expm1(y.get_label())
    yhat = np.expm1(yhat)
    return "rmspe", rmspe(y, yhat)

# %%
# base parameters
params = {
    'booster': 'gbtree', 
    'objective': 'reg:linear', # regression task
    'subsample': 0.8, # 80% of data to grow trees and prevent overfitting
    'colsample_bytree': 0.85, # 85% of features used
    'eta': 0.1, 
    'max_depth': 10, 
    'seed': 42} # for reproducible results

# %%
# XGB with xgboost library
dtrain = xgb.DMatrix(X_train[predictors], y_train)
dtest = xgb.DMatrix(X_test[predictors], y_test)

watchlist = [(dtrain, 'train'), (dtest, 'test')]

xgb_model = xgb.train(params, dtrain, 300, evals = watchlist,
                      early_stopping_rounds = 50, feval = rmspe_xg, verbose_eval = True)
# Out:
# [10:40:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	train-rmse:7.44354	test-rmse:7.44325	train-rmspe:0.999526	test-rmspe:0.999526
# Multiple eval metrics have been passed: 'test-rmspe' will be used for early stopping.
#
# Will train until test-rmspe hasn't improved in 50 rounds.
# [1]	train-rmse:6.70092	test-rmse:6.70061	train-rmspe:0.998821	test-rmspe:0.998822
# [2]	train-rmse:6.03272	test-rmse:6.03246	train-rmspe:0.997548	test-rmspe:0.997549
# [3]	train-rmse:5.43142	test-rmse:5.43115	train-rmspe:0.995407	test-rmspe:0.995409
# [4]	train-rmse:4.89039	test-rmse:4.8901	train-rmspe:0.992014	test-rmspe:0.992017
# [5]	train-rmse:4.40369	test-rmse:4.40343	train-rmspe:0.986934	test-rmspe:0.986938
# [6]	train-rmse:3.96585	test-rmse:3.96556	train-rmspe:0.979716	test-rmspe:0.97972
# [7]	train-rmse:3.57203	test-rmse:3.57171	train-rmspe:0.96991	test-rmspe:0.969911
# [8]	train-rmse:3.21774	test-rmse:3.21743	train-rmspe:0.957129	test-rmspe:0.957125
# [9]	train-rmse:2.89887	test-rmse:2.89857	train-rmspe:0.94114	test-rmspe:0.941121
# [10]	train-rmse:2.61219	test-rmse:2.61189	train-rmspe:0.921738	test-rmspe:0.921692
# [11]	train-rmse:2.35466	test-rmse:2.35431	train-rmspe:0.898869	test-rmspe:0.898775
# [12]	train-rmse:2.12297	test-rmse:2.12263	train-rmspe:0.872758	test-rmspe:0.872591
# [13]	train-rmse:1.91493	test-rmse:1.91461	train-rmspe:0.84356	test-rmspe:0.843272
# [14]	train-rmse:1.72816	test-rmse:1.72782	train-rmspe:0.811725	test-rmspe:0.811273
# [15]	train-rmse:1.56056	test-rmse:1.56023	train-rmspe:0.777738	test-rmspe:0.777052
# [16]	train-rmse:1.40906	test-rmse:1.40876	train-rmspe:0.742382	test-rmspe:0.741384
# [17]	train-rmse:1.27401	test-rmse:1.27373	train-rmspe:0.705766	test-rmspe:0.704367
# [18]	train-rmse:1.15282	test-rmse:1.15256	train-rmspe:0.668757	test-rmspe:0.666844
# [19]	train-rmse:1.04448	test-rmse:1.04419	train-rmspe:0.631726	test-rmspe:0.629264
# [20]	train-rmse:0.947761	test-rmse:0.947488	train-rmspe:0.595289	test-rmspe:0.592196
# [21]	train-rmse:0.860421	test-rmse:0.860204	train-rmspe:0.56	test-rmspe:0.556184
# [22]	train-rmse:0.783274	test-rmse:0.783065	train-rmspe:0.526325	test-rmspe:0.521536
# [23]	train-rmse:0.714625	test-rmse:0.714461	train-rmspe:0.49442	test-rmspe:0.48864
# [24]	train-rmse:0.65325	test-rmse:0.653116	train-rmspe:0.464769	test-rmspe:0.45771
# [25]	train-rmse:0.595809	test-rmse:0.595766	train-rmspe:0.436887	test-rmspe:0.428137
# [26]	train-rmse:0.547145	test-rmse:0.547144	train-rmspe:0.411654	test-rmspe:0.401458
# [27]	train-rmse:0.503849	test-rmse:0.503897	train-rmspe:0.388975	test-rmspe:0.377034
# [28]	train-rmse:0.465586	test-rmse:0.46566	train-rmspe:0.368795	test-rmspe:0.355063
# [29]	train-rmse:0.431986	test-rmse:0.432121	train-rmspe:0.351142	test-rmspe:0.335432
# [30]	train-rmse:0.402258	test-rmse:0.402429	train-rmspe:0.335654	test-rmspe:0.318023
# [31]	train-rmse:0.377435	test-rmse:0.377693	train-rmspe:0.3231	test-rmspe:0.30365
# [32]	train-rmse:0.355385	test-rmse:0.355686	train-rmspe:0.312326	test-rmspe:0.290911
# [33]	train-rmse:0.33618	test-rmse:0.336576	train-rmspe:0.30338	test-rmspe:0.280216
# [34]	train-rmse:0.319798	test-rmse:0.320225	train-rmspe:0.296485	test-rmspe:0.271481
# [35]	train-rmse:0.305247	test-rmse:0.305727	train-rmspe:0.290583	test-rmspe:0.263988
# [36]	train-rmse:0.291391	test-rmse:0.29191	train-rmspe:0.284806	test-rmspe:0.256412
# [37]	train-rmse:0.278669	test-rmse:0.279243	train-rmspe:0.279594	test-rmspe:0.249259
# [38]	train-rmse:0.267472	test-rmse:0.268115	train-rmspe:0.275432	test-rmspe:0.243369
# [39]	train-rmse:0.257666	test-rmse:0.258345	train-rmspe:0.271682	test-rmspe:0.238125
# [40]	train-rmse:0.251261	test-rmse:0.252024	train-rmspe:0.26943	test-rmspe:0.235827
# [41]	train-rmse:0.244698	test-rmse:0.24556	train-rmspe:0.267839	test-rmspe:0.23318
# [42]	train-rmse:0.239795	test-rmse:0.24078	train-rmspe:0.266482	test-rmspe:0.231711
# [43]	train-rmse:0.234882	test-rmse:0.23598	train-rmspe:0.265355	test-rmspe:0.229895
# [44]	train-rmse:0.23004	test-rmse:0.23119	train-rmspe:0.263666	test-rmspe:0.227581
# [45]	train-rmse:0.22714	test-rmse:0.228365	train-rmspe:0.26392	test-rmspe:0.22722
# [46]	train-rmse:0.22369	test-rmse:0.224982	train-rmspe:0.263143	test-rmspe:0.225929
# [47]	train-rmse:0.217977	test-rmse:0.219337	train-rmspe:0.260224	test-rmspe:0.222006
# [48]	train-rmse:0.213497	test-rmse:0.214898	train-rmspe:0.258118	test-rmspe:0.219244
# [49]	train-rmse:0.211607	test-rmse:0.213121	train-rmspe:0.257104	test-rmspe:0.218905
# [50]	train-rmse:0.20816	test-rmse:0.209737	train-rmspe:0.255548	test-rmspe:0.216689
# [51]	train-rmse:0.206723	test-rmse:0.208408	train-rmspe:0.256174	test-rmspe:0.216579
# [52]	train-rmse:0.205797	test-rmse:0.207499	train-rmspe:0.25507	test-rmspe:0.21677
# [53]	train-rmse:0.202398	test-rmse:0.204114	train-rmspe:0.253133	test-rmspe:0.214054
# [54]	train-rmse:0.199088	test-rmse:0.200832	train-rmspe:0.251092	test-rmspe:0.21149
# [55]	train-rmse:0.197969	test-rmse:0.199712	train-rmspe:0.247416	test-rmspe:0.211098
# [56]	train-rmse:0.197063	test-rmse:0.198902	train-rmspe:0.247351	test-rmspe:0.210985
# [57]	train-rmse:0.196247	test-rmse:0.198169	train-rmspe:0.243217	test-rmspe:0.210865
# [58]	train-rmse:0.192873	test-rmse:0.194812	train-rmspe:0.240632	test-rmspe:0.207825
# [59]	train-rmse:0.18884	test-rmse:0.190796	train-rmspe:0.237634	test-rmspe:0.203859
# [60]	train-rmse:0.187084	test-rmse:0.189053	train-rmspe:0.235963	test-rmspe:0.202269
# [61]	train-rmse:0.185873	test-rmse:0.187878	train-rmspe:0.235351	test-rmspe:0.201445
# [62]	train-rmse:0.185607	test-rmse:0.187627	train-rmspe:0.235151	test-rmspe:0.201547
# [63]	train-rmse:0.185107	test-rmse:0.187135	train-rmspe:0.235011	test-rmspe:0.201303
# [64]	train-rmse:0.184124	test-rmse:0.186203	train-rmspe:0.234418	test-rmspe:0.200539
# [65]	train-rmse:0.183346	test-rmse:0.185468	train-rmspe:0.233981	test-rmspe:0.200026
# [66]	train-rmse:0.182908	test-rmse:0.185082	train-rmspe:0.233778	test-rmspe:0.199848
# [67]	train-rmse:0.181265	test-rmse:0.183463	train-rmspe:0.23258	test-rmspe:0.198482
# [68]	train-rmse:0.178618	test-rmse:0.180805	train-rmspe:0.23021	test-rmspe:0.195602
# [69]	train-rmse:0.177783	test-rmse:0.17998	train-rmspe:0.229681	test-rmspe:0.194929
# [70]	train-rmse:0.175569	test-rmse:0.177824	train-rmspe:0.227737	test-rmspe:0.192644
# [71]	train-rmse:0.175294	test-rmse:0.177565	train-rmspe:0.227665	test-rmspe:0.19251
# [72]	train-rmse:0.174415	test-rmse:0.176704	train-rmspe:0.22791	test-rmspe:0.191585
# [73]	train-rmse:0.173057	test-rmse:0.175375	train-rmspe:0.226883	test-rmspe:0.190325
# [74]	train-rmse:0.172125	test-rmse:0.174449	train-rmspe:0.225994	test-rmspe:0.189459
# [75]	train-rmse:0.169079	test-rmse:0.171449	train-rmspe:0.223531	test-rmspe:0.186261
# [76]	train-rmse:0.168792	test-rmse:0.171185	train-rmspe:0.22326	test-rmspe:0.186053
# [77]	train-rmse:0.166986	test-rmse:0.169433	train-rmspe:0.221746	test-rmspe:0.184282
# [78]	train-rmse:0.16648	test-rmse:0.169022	train-rmspe:0.221071	test-rmspe:0.183874
# [79]	train-rmse:0.164516	test-rmse:0.167085	train-rmspe:0.21899	test-rmspe:0.18174
# [80]	train-rmse:0.16357	test-rmse:0.166185	train-rmspe:0.218254	test-rmspe:0.180858
# [81]	train-rmse:0.162833	test-rmse:0.165497	train-rmspe:0.216995	test-rmspe:0.180046
# [82]	train-rmse:0.161352	test-rmse:0.16404	train-rmspe:0.215777	test-rmspe:0.178502
# [83]	train-rmse:0.160264	test-rmse:0.162971	train-rmspe:0.214219	test-rmspe:0.177427
# [84]	train-rmse:0.158781	test-rmse:0.161548	train-rmspe:0.212852	test-rmspe:0.175894
# [85]	train-rmse:0.157241	test-rmse:0.16004	train-rmspe:0.211531	test-rmspe:0.174235
# [86]	train-rmse:0.156624	test-rmse:0.159441	train-rmspe:0.211047	test-rmspe:0.173639
# [87]	train-rmse:0.155489	test-rmse:0.158312	train-rmspe:0.210168	test-rmspe:0.172502
# [88]	train-rmse:0.15509	test-rmse:0.157979	train-rmspe:0.209615	test-rmspe:0.172131
# [89]	train-rmse:0.154935	test-rmse:0.157838	train-rmspe:0.209482	test-rmspe:0.171988
# [90]	train-rmse:0.153007	test-rmse:0.155967	train-rmspe:0.207889	test-rmspe:0.170064
# [91]	train-rmse:0.152435	test-rmse:0.155406	train-rmspe:0.208116	test-rmspe:0.169453
# [92]	train-rmse:0.151617	test-rmse:0.154613	train-rmspe:0.207187	test-rmspe:0.168652
# [93]	train-rmse:0.150528	test-rmse:0.153553	train-rmspe:0.206302	test-rmspe:0.167564
# [94]	train-rmse:0.149746	test-rmse:0.152836	train-rmspe:0.20561	test-rmspe:0.166806
# [95]	train-rmse:0.148477	test-rmse:0.151603	train-rmspe:0.204515	test-rmspe:0.16544
# [96]	train-rmse:0.14799	test-rmse:0.151125	train-rmspe:0.204064	test-rmspe:0.164925
# [97]	train-rmse:0.14767	test-rmse:0.150872	train-rmspe:0.203455	test-rmspe:0.164545
# [98]	train-rmse:0.14683	test-rmse:0.150086	train-rmspe:0.198463	test-rmspe:0.163582
# [99]	train-rmse:0.146194	test-rmse:0.149476	train-rmspe:0.198173	test-rmspe:0.162926
# [100]	train-rmse:0.145372	test-rmse:0.148669	train-rmspe:0.191117	test-rmspe:0.161971
# [101]	train-rmse:0.144699	test-rmse:0.148031	train-rmspe:0.190542	test-rmspe:0.161338
# [102]	train-rmse:0.144045	test-rmse:0.147399	train-rmspe:0.189476	test-rmspe:0.160677
# [103]	train-rmse:0.143575	test-rmse:0.146948	train-rmspe:0.189062	test-rmspe:0.160197
# [104]	train-rmse:0.143173	test-rmse:0.146577	train-rmspe:0.188382	test-rmspe:0.159843
# [105]	train-rmse:0.141264	test-rmse:0.144708	train-rmspe:0.186762	test-rmspe:0.157957
# [106]	train-rmse:0.139895	test-rmse:0.143373	train-rmspe:0.185005	test-rmspe:0.15647
# [107]	train-rmse:0.139468	test-rmse:0.143007	train-rmspe:0.184484	test-rmspe:0.156098
# [108]	train-rmse:0.13902	test-rmse:0.142592	train-rmspe:0.183921	test-rmspe:0.155687
# [109]	train-rmse:0.138656	test-rmse:0.142296	train-rmspe:0.180788	test-rmspe:0.155384
# [110]	train-rmse:0.138028	test-rmse:0.141686	train-rmspe:0.180216	test-rmspe:0.154714
# [111]	train-rmse:0.136687	test-rmse:0.140374	train-rmspe:0.178983	test-rmspe:0.153333
# [112]	train-rmse:0.136309	test-rmse:0.140066	train-rmspe:0.177554	test-rmspe:0.153007
# [113]	train-rmse:0.135786	test-rmse:0.139571	train-rmspe:0.177122	test-rmspe:0.152515
# [114]	train-rmse:0.135081	test-rmse:0.138889	train-rmspe:0.176546	test-rmspe:0.151831
# [115]	train-rmse:0.134887	test-rmse:0.138717	train-rmspe:0.177009	test-rmspe:0.151664
# [116]	train-rmse:0.133727	test-rmse:0.13758	train-rmspe:0.175877	test-rmspe:0.15032
# [117]	train-rmse:0.13313	test-rmse:0.137034	train-rmspe:0.175286	test-rmspe:0.149731
# [118]	train-rmse:0.132678	test-rmse:0.1366	train-rmspe:0.174704	test-rmspe:0.149254
# [119]	train-rmse:0.132314	test-rmse:0.136253	train-rmspe:0.17439	test-rmspe:0.1489
# [120]	train-rmse:0.132209	test-rmse:0.13615	train-rmspe:0.174392	test-rmspe:0.148797
# [121]	train-rmse:0.131738	test-rmse:0.135711	train-rmspe:0.173978	test-rmspe:0.148335
# [122]	train-rmse:0.131644	test-rmse:0.13563	train-rmspe:0.17388	test-rmspe:0.148255
# [123]	train-rmse:0.131261	test-rmse:0.135266	train-rmspe:0.173548	test-rmspe:0.147881
# [124]	train-rmse:0.130532	test-rmse:0.134622	train-rmspe:0.172688	test-rmspe:0.147137
# [125]	train-rmse:0.129714	test-rmse:0.133839	train-rmspe:0.171942	test-rmspe:0.14635
# [126]	train-rmse:0.129245	test-rmse:0.133386	train-rmspe:0.17149	test-rmspe:0.145824
# [127]	train-rmse:0.128625	test-rmse:0.132803	train-rmspe:0.170727	test-rmspe:0.14519
# [128]	train-rmse:0.128291	test-rmse:0.1325	train-rmspe:0.170446	test-rmspe:0.144888
# [129]	train-rmse:0.128148	test-rmse:0.13237	train-rmspe:0.170939	test-rmspe:0.14476
# [130]	train-rmse:0.127829	test-rmse:0.1321	train-rmspe:0.170643	test-rmspe:0.144482
# [131]	train-rmse:0.127151	test-rmse:0.131459	train-rmspe:0.170077	test-rmspe:0.143845
# [132]	train-rmse:0.126273	test-rmse:0.130615	train-rmspe:0.16925	test-rmspe:0.142952
# [133]	train-rmse:0.125753	test-rmse:0.130147	train-rmspe:0.168792	test-rmspe:0.142491
# [134]	train-rmse:0.125418	test-rmse:0.12982	train-rmspe:0.168495	test-rmspe:0.142117
# [135]	train-rmse:0.124124	test-rmse:0.128587	train-rmspe:0.167251	test-rmspe:0.140789
# [136]	train-rmse:0.123341	test-rmse:0.127846	train-rmspe:0.166637	test-rmspe:0.139993
# [137]	train-rmse:0.123101	test-rmse:0.127654	train-rmspe:0.16642	test-rmspe:0.139789
# [138]	train-rmse:0.122591	test-rmse:0.127181	train-rmspe:0.165913	test-rmspe:0.13932
# [139]	train-rmse:0.121855	test-rmse:0.126485	train-rmspe:0.165114	test-rmspe:0.138581
# [140]	train-rmse:0.121603	test-rmse:0.126269	train-rmspe:0.163297	test-rmspe:0.138358
# [141]	train-rmse:0.12132	test-rmse:0.126032	train-rmspe:0.16298	test-rmspe:0.138088
# [142]	train-rmse:0.120839	test-rmse:0.125577	train-rmspe:0.162502	test-rmspe:0.137583
# [143]	train-rmse:0.120491	test-rmse:0.125337	train-rmspe:0.161988	test-rmspe:0.137228
# [144]	train-rmse:0.119883	test-rmse:0.124773	train-rmspe:0.161461	test-rmspe:0.136658
# [145]	train-rmse:0.119634	test-rmse:0.124551	train-rmspe:0.161239	test-rmspe:0.136439
# [146]	train-rmse:0.119063	test-rmse:0.124005	train-rmspe:0.160769	test-rmspe:0.135886
# [147]	train-rmse:0.118735	test-rmse:0.123723	train-rmspe:0.160491	test-rmspe:0.135604
# [148]	train-rmse:0.118029	test-rmse:0.123062	train-rmspe:0.159878	test-rmspe:0.134916
# [149]	train-rmse:0.117767	test-rmse:0.122808	train-rmspe:0.159654	test-rmspe:0.134641
# [150]	train-rmse:0.117197	test-rmse:0.12227	train-rmspe:0.159188	test-rmspe:0.134104
# [151]	train-rmse:0.116805	test-rmse:0.121928	train-rmspe:0.158778	test-rmspe:0.133741
# [152]	train-rmse:0.116584	test-rmse:0.12174	train-rmspe:0.158592	test-rmspe:0.133556
# [153]	train-rmse:0.116082	test-rmse:0.12127	train-rmspe:0.158183	test-rmspe:0.133076
# [154]	train-rmse:0.115591	test-rmse:0.120809	train-rmspe:0.15776	test-rmspe:0.132588
# [155]	train-rmse:0.114974	test-rmse:0.120257	train-rmspe:0.1571	test-rmspe:0.131934
# [156]	train-rmse:0.114799	test-rmse:0.120121	train-rmspe:0.156896	test-rmspe:0.131797
# [157]	train-rmse:0.114432	test-rmse:0.119779	train-rmspe:0.1566	test-rmspe:0.131437
# [158]	train-rmse:0.114151	test-rmse:0.119519	train-rmspe:0.157484	test-rmspe:0.131148
# [159]	train-rmse:0.113783	test-rmse:0.11919	train-rmspe:0.1572	test-rmspe:0.130831
# [160]	train-rmse:0.113532	test-rmse:0.118961	train-rmspe:0.157011	test-rmspe:0.130599
# [161]	train-rmse:0.113313	test-rmse:0.118768	train-rmspe:0.156801	test-rmspe:0.130404
# [162]	train-rmse:0.113156	test-rmse:0.118629	train-rmspe:0.156678	test-rmspe:0.130268
# [163]	train-rmse:0.112696	test-rmse:0.118208	train-rmspe:0.156283	test-rmspe:0.129814
# [164]	train-rmse:0.112343	test-rmse:0.117892	train-rmspe:0.156058	test-rmspe:0.129478
# [165]	train-rmse:0.112099	test-rmse:0.117662	train-rmspe:0.155839	test-rmspe:0.129246
# [166]	train-rmse:0.111273	test-rmse:0.116914	train-rmspe:0.155115	test-rmspe:0.128448
# [167]	train-rmse:0.11114	test-rmse:0.116817	train-rmspe:0.154969	test-rmspe:0.128362
# [168]	train-rmse:0.110874	test-rmse:0.116576	train-rmspe:0.155722	test-rmspe:0.128091
# [169]	train-rmse:0.110439	test-rmse:0.116208	train-rmspe:0.155367	test-rmspe:0.127702
# [170]	train-rmse:0.110208	test-rmse:0.115999	train-rmspe:0.155107	test-rmspe:0.127504
# [171]	train-rmse:0.109979	test-rmse:0.1158	train-rmspe:0.145249	test-rmspe:0.127285
# [172]	train-rmse:0.109691	test-rmse:0.115553	train-rmspe:0.144967	test-rmspe:0.127038
# [173]	train-rmse:0.109434	test-rmse:0.115332	train-rmspe:0.144758	test-rmspe:0.126818
# [174]	train-rmse:0.109252	test-rmse:0.115172	train-rmspe:0.144595	test-rmspe:0.126656
# [175]	train-rmse:0.108951	test-rmse:0.114921	train-rmspe:0.144334	test-rmspe:0.126404
# [176]	train-rmse:0.108808	test-rmse:0.114833	train-rmspe:0.142986	test-rmspe:0.126257
# [177]	train-rmse:0.10861	test-rmse:0.114688	train-rmspe:0.142812	test-rmspe:0.126107
# [178]	train-rmse:0.108466	test-rmse:0.114577	train-rmspe:0.142692	test-rmspe:0.126
# [179]	train-rmse:0.108205	test-rmse:0.114359	train-rmspe:0.142457	test-rmspe:0.125786
# [180]	train-rmse:0.10802	test-rmse:0.11423	train-rmspe:0.142243	test-rmspe:0.125661
# [181]	train-rmse:0.107726	test-rmse:0.113976	train-rmspe:0.141927	test-rmspe:0.125347
# [182]	train-rmse:0.107459	test-rmse:0.113733	train-rmspe:0.141655	test-rmspe:0.125088
# [183]	train-rmse:0.107239	test-rmse:0.113587	train-rmspe:0.134901	test-rmspe:0.124915
# [184]	train-rmse:0.107036	test-rmse:0.11345	train-rmspe:0.134569	test-rmspe:0.124651
# [185]	train-rmse:0.106753	test-rmse:0.113194	train-rmspe:0.134317	test-rmspe:0.124376
# [186]	train-rmse:0.106573	test-rmse:0.113028	train-rmspe:0.134377	test-rmspe:0.124212
# [187]	train-rmse:0.106432	test-rmse:0.112906	train-rmspe:0.134262	test-rmspe:0.124096
# [188]	train-rmse:0.105956	test-rmse:0.112493	train-rmspe:0.133833	test-rmspe:0.123657
# [189]	train-rmse:0.10579	test-rmse:0.112361	train-rmspe:0.133649	test-rmspe:0.123518
# [190]	train-rmse:0.105733	test-rmse:0.112312	train-rmspe:0.133606	test-rmspe:0.123476
# [191]	train-rmse:0.105447	test-rmse:0.112042	train-rmspe:0.133348	test-rmspe:0.123198
# [192]	train-rmse:0.105416	test-rmse:0.112019	train-rmspe:0.133325	test-rmspe:0.123177
# [193]	train-rmse:0.105212	test-rmse:0.11188	train-rmspe:0.133025	test-rmspe:0.122988
# [194]	train-rmse:0.105043	test-rmse:0.111748	train-rmspe:0.132866	test-rmspe:0.122855
# [195]	train-rmse:0.104736	test-rmse:0.111471	train-rmspe:0.132567	test-rmspe:0.122575
# [196]	train-rmse:0.104647	test-rmse:0.111399	train-rmspe:0.132467	test-rmspe:0.1225
# [197]	train-rmse:0.104504	test-rmse:0.111299	train-rmspe:0.132329	test-rmspe:0.1224
# [198]	train-rmse:0.104231	test-rmse:0.111058	train-rmspe:0.132111	test-rmspe:0.122153
# [199]	train-rmse:0.103971	test-rmse:0.110831	train-rmspe:0.131877	test-rmspe:0.121923
# [200]	train-rmse:0.103774	test-rmse:0.110678	train-rmspe:0.131631	test-rmspe:0.121764
# [201]	train-rmse:0.103691	test-rmse:0.110632	train-rmspe:0.131549	test-rmspe:0.121725
# [202]	train-rmse:0.103531	test-rmse:0.110518	train-rmspe:0.131425	test-rmspe:0.12161
# [203]	train-rmse:0.103392	test-rmse:0.110408	train-rmspe:0.131298	test-rmspe:0.121477
# [204]	train-rmse:0.103178	test-rmse:0.11023	train-rmspe:0.131091	test-rmspe:0.121295
# [205]	train-rmse:0.102834	test-rmse:0.109936	train-rmspe:0.130788	test-rmspe:0.121001
# [206]	train-rmse:0.10274	test-rmse:0.109866	train-rmspe:0.130705	test-rmspe:0.120928
# [207]	train-rmse:0.102679	test-rmse:0.109818	train-rmspe:0.131107	test-rmspe:0.120879
# [208]	train-rmse:0.102569	test-rmse:0.109719	train-rmspe:0.131014	test-rmspe:0.120774
# [209]	train-rmse:0.102433	test-rmse:0.109613	train-rmspe:0.130882	test-rmspe:0.120675
# [210]	train-rmse:0.102193	test-rmse:0.109417	train-rmspe:0.13061	test-rmspe:0.12046
# [211]	train-rmse:0.102071	test-rmse:0.109318	train-rmspe:0.130505	test-rmspe:0.120361
# [212]	train-rmse:0.101956	test-rmse:0.109254	train-rmspe:0.130393	test-rmspe:0.120306
# [213]	train-rmse:0.101799	test-rmse:0.109134	train-rmspe:0.125467	test-rmspe:0.120173
# [214]	train-rmse:0.101447	test-rmse:0.108828	train-rmspe:0.125132	test-rmspe:0.119858
# [215]	train-rmse:0.101286	test-rmse:0.1087	train-rmspe:0.124983	test-rmspe:0.119733
# [216]	train-rmse:0.100975	test-rmse:0.108429	train-rmspe:0.124818	test-rmspe:0.119459
# [217]	train-rmse:0.100859	test-rmse:0.108335	train-rmspe:0.124702	test-rmspe:0.119363
# [218]	train-rmse:0.100706	test-rmse:0.108224	train-rmspe:0.124556	test-rmspe:0.119252
# [219]	train-rmse:0.100384	test-rmse:0.107953	train-rmspe:0.124266	test-rmspe:0.118981
# [220]	train-rmse:0.100194	test-rmse:0.107801	train-rmspe:0.124101	test-rmspe:0.118836
# [221]	train-rmse:0.100002	test-rmse:0.107632	train-rmspe:0.12392	test-rmspe:0.118663
# [222]	train-rmse:0.099842	test-rmse:0.107502	train-rmspe:0.123745	test-rmspe:0.11854
# [223]	train-rmse:0.099678	test-rmse:0.107375	train-rmspe:0.123586	test-rmspe:0.11842
# [224]	train-rmse:0.099446	test-rmse:0.107191	train-rmspe:0.123366	test-rmspe:0.118232
# [225]	train-rmse:0.099293	test-rmse:0.107069	train-rmspe:0.123219	test-rmspe:0.118113
# [226]	train-rmse:0.099165	test-rmse:0.106984	train-rmspe:0.11983	test-rmspe:0.118033
# [227]	train-rmse:0.099094	test-rmse:0.106938	train-rmspe:0.119757	test-rmspe:0.11799
# [228]	train-rmse:0.098987	test-rmse:0.106846	train-rmspe:0.119574	test-rmspe:0.117901
# [229]	train-rmse:0.09871	test-rmse:0.106609	train-rmspe:0.119305	test-rmspe:0.117657
# [230]	train-rmse:0.098593	test-rmse:0.10653	train-rmspe:0.119191	test-rmspe:0.117581
# [231]	train-rmse:0.098521	test-rmse:0.106482	train-rmspe:0.119119	test-rmspe:0.117521
# [232]	train-rmse:0.098381	test-rmse:0.106378	train-rmspe:0.118977	test-rmspe:0.117424
# [233]	train-rmse:0.098262	test-rmse:0.10629	train-rmspe:0.118809	test-rmspe:0.117346
# [234]	train-rmse:0.098064	test-rmse:0.106151	train-rmspe:0.117765	test-rmspe:0.117171
# [235]	train-rmse:0.097847	test-rmse:0.105998	train-rmspe:0.115579	test-rmspe:0.116993
# [236]	train-rmse:0.097741	test-rmse:0.105923	train-rmspe:0.115482	test-rmspe:0.116928
# [237]	train-rmse:0.097583	test-rmse:0.105845	train-rmspe:0.115138	test-rmspe:0.11681
# [238]	train-rmse:0.097411	test-rmse:0.105725	train-rmspe:0.114716	test-rmspe:0.116676
# [239]	train-rmse:0.097244	test-rmse:0.105596	train-rmspe:0.114532	test-rmspe:0.116533
# [240]	train-rmse:0.097011	test-rmse:0.105406	train-rmspe:0.114242	test-rmspe:0.116332
# [241]	train-rmse:0.096973	test-rmse:0.105377	train-rmspe:0.113804	test-rmspe:0.116291
# [242]	train-rmse:0.096829	test-rmse:0.10527	train-rmspe:0.113592	test-rmspe:0.116189
# [243]	train-rmse:0.096668	test-rmse:0.105142	train-rmspe:0.113434	test-rmspe:0.116059
# [244]	train-rmse:0.096583	test-rmse:0.105074	train-rmspe:0.113354	test-rmspe:0.115991
# [245]	train-rmse:0.096371	test-rmse:0.104904	train-rmspe:0.113138	test-rmspe:0.115817
# [246]	train-rmse:0.096289	test-rmse:0.104843	train-rmspe:0.113053	test-rmspe:0.115752
# [247]	train-rmse:0.096192	test-rmse:0.104776	train-rmspe:0.112944	test-rmspe:0.115684
# [248]	train-rmse:0.096102	test-rmse:0.104712	train-rmspe:0.112841	test-rmspe:0.115606
# [249]	train-rmse:0.095949	test-rmse:0.104638	train-rmspe:0.112526	test-rmspe:0.11543
# [250]	train-rmse:0.095856	test-rmse:0.104562	train-rmspe:0.112285	test-rmspe:0.115342
# [251]	train-rmse:0.095662	test-rmse:0.104413	train-rmspe:0.11212	test-rmspe:0.115202
# [252]	train-rmse:0.095473	test-rmse:0.104263	train-rmspe:0.111944	test-rmspe:0.115059
# [253]	train-rmse:0.095353	test-rmse:0.104168	train-rmspe:0.111819	test-rmspe:0.114968
# [254]	train-rmse:0.095187	test-rmse:0.104029	train-rmspe:0.111635	test-rmspe:0.114827
# [255]	train-rmse:0.095017	test-rmse:0.103903	train-rmspe:0.111451	test-rmspe:0.114708
# [256]	train-rmse:0.094919	test-rmse:0.103837	train-rmspe:0.111351	test-rmspe:0.114632
# [257]	train-rmse:0.094765	test-rmse:0.103729	train-rmspe:0.111193	test-rmspe:0.114527
# [258]	train-rmse:0.094657	test-rmse:0.103655	train-rmspe:0.111073	test-rmspe:0.11446
# [259]	train-rmse:0.094479	test-rmse:0.103524	train-rmspe:0.110925	test-rmspe:0.114328
# [260]	train-rmse:0.094389	test-rmse:0.103461	train-rmspe:0.110835	test-rmspe:0.114258
# [261]	train-rmse:0.094264	test-rmse:0.103372	train-rmspe:0.109789	test-rmspe:0.114161
# [262]	train-rmse:0.09424	test-rmse:0.103358	train-rmspe:0.109767	test-rmspe:0.114145
# [263]	train-rmse:0.094132	test-rmse:0.103298	train-rmspe:0.109662	test-rmspe:0.114091
# [264]	train-rmse:0.093989	test-rmse:0.103194	train-rmspe:0.109521	test-rmspe:0.11399
# [265]	train-rmse:0.093876	test-rmse:0.10312	train-rmspe:0.109413	test-rmspe:0.113891
# [266]	train-rmse:0.093783	test-rmse:0.103048	train-rmspe:0.109323	test-rmspe:0.11382
# [267]	train-rmse:0.093672	test-rmse:0.102968	train-rmspe:0.109204	test-rmspe:0.113733
# [268]	train-rmse:0.093568	test-rmse:0.102898	train-rmspe:0.109098	test-rmspe:0.113665
# [269]	train-rmse:0.093498	test-rmse:0.102846	train-rmspe:0.109024	test-rmspe:0.113606
# [270]	train-rmse:0.093435	test-rmse:0.102807	train-rmspe:0.108966	test-rmspe:0.11357
# [271]	train-rmse:0.093283	test-rmse:0.102703	train-rmspe:0.108795	test-rmspe:0.113466
# [272]	train-rmse:0.093238	test-rmse:0.102689	train-rmspe:0.108746	test-rmspe:0.113452
# [273]	train-rmse:0.093107	test-rmse:0.1026	train-rmspe:0.108617	test-rmspe:0.113366
# [274]	train-rmse:0.093001	test-rmse:0.102527	train-rmspe:0.108501	test-rmspe:0.11329
# [275]	train-rmse:0.092981	test-rmse:0.102523	train-rmspe:0.108481	test-rmspe:0.113282
# [276]	train-rmse:0.092933	test-rmse:0.1025	train-rmspe:0.107992	test-rmspe:0.113262
# [277]	train-rmse:0.092791	test-rmse:0.102404	train-rmspe:0.107815	test-rmspe:0.11318
# [278]	train-rmse:0.092706	test-rmse:0.102351	train-rmspe:0.107719	test-rmspe:0.11313
# [279]	train-rmse:0.092632	test-rmse:0.10231	train-rmspe:0.107645	test-rmspe:0.113096
# [280]	train-rmse:0.092565	test-rmse:0.102264	train-rmspe:0.107573	test-rmspe:0.113051
# [281]	train-rmse:0.092442	test-rmse:0.102178	train-rmspe:0.10745	test-rmspe:0.112972
# [282]	train-rmse:0.09233	test-rmse:0.102107	train-rmspe:0.107293	test-rmspe:0.112847
# [283]	train-rmse:0.092215	test-rmse:0.102018	train-rmspe:0.107173	test-rmspe:0.112761
# [284]	train-rmse:0.092123	test-rmse:0.101951	train-rmspe:0.107025	test-rmspe:0.112683
# [285]	train-rmse:0.091976	test-rmse:0.10184	train-rmspe:0.106623	test-rmspe:0.112563
# [286]	train-rmse:0.091866	test-rmse:0.101785	train-rmspe:0.106392	test-rmspe:0.112416
# [287]	train-rmse:0.091839	test-rmse:0.101771	train-rmspe:0.106363	test-rmspe:0.112397
# [288]	train-rmse:0.091727	test-rmse:0.101686	train-rmspe:0.106248	test-rmspe:0.112318
# [289]	train-rmse:0.091642	test-rmse:0.101636	train-rmspe:0.106159	test-rmspe:0.112265
# [290]	train-rmse:0.091618	test-rmse:0.101628	train-rmspe:0.10613	test-rmspe:0.112257
# [291]	train-rmse:0.091513	test-rmse:0.101565	train-rmspe:0.105974	test-rmspe:0.112194
# [292]	train-rmse:0.091376	test-rmse:0.101445	train-rmspe:0.105844	test-rmspe:0.112077
# [293]	train-rmse:0.091306	test-rmse:0.101407	train-rmspe:0.105778	test-rmspe:0.112042
# [294]	train-rmse:0.09114	test-rmse:0.101282	train-rmspe:0.105607	test-rmspe:0.11194
# [295]	train-rmse:0.090947	test-rmse:0.101129	train-rmspe:0.105419	test-rmspe:0.111795
# [296]	train-rmse:0.090845	test-rmse:0.101062	train-rmspe:0.105316	test-rmspe:0.11172
# [297]	train-rmse:0.090719	test-rmse:0.10097	train-rmspe:0.105183	test-rmspe:0.111623
# [298]	train-rmse:0.090618	test-rmse:0.100898	train-rmspe:0.104164	test-rmspe:0.111554
# [299]	train-rmse:0.090497	test-rmse:0.100814	train-rmspe:0.104108	test-rmspe:0.111471

# %% [markdown]
# Last 5 rows:
#
# [295] train-rmspe:0.105419	  test-rmspe:0.111795
#
# [296] train-rmspe:0.105316   	test-rmspe:0.11172
#
# [297] train-rmspe:0.105183	  test-rmspe:0.111623
#
# [298] train-rmspe:0.104164	  test-rmspe:0.111554
#
# [299] train-rmspe:0.104108	  test-rmspe:0.111471

# %% [markdown]
# **Essentially, we want the least value. The model with base hyperparameters gives out better resukt on the train set, indicating to the overfitting issue.**

# %% [markdown]
# **Grid Search from sklearn**
#
# Scikit learn wrapper is famous for the GridSearchCV and RandomizedSearchCV. Between these two, most of the time the preference leans towards RandomnizedSearchCV, faster version of GridSearchCV.
#
# As an input, RandomnizedSearchCV takes only sklearn wrapper of XGboost, so instead of using the first version of a model, we build the analogous model in sklearn with XGBRegressor.

# %%
# XGB with sklearn wrapper
# the same parameters as for xgboost model

params_sk = {'max_depth': 10, 
            'n_estimators': 300, # the same as num_rounds in xgboost
            'objective': 'reg:linear', 
            'subsample': 0.8, 
            'colsample_bytree': 0.85, 
            'learning_rate': 0.1, 
            'seed': 42}     

skrg = XGBRegressor(**params_sk)

skrg.fit(X_train, y_train)
# Out:
# [11:21:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.85, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=10, min_child_weight=1, missing=None, n_estimators=300,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=42,
#              silent=None, subsample=0.8, verbosity=1)

# %% [markdown]
# For parameters we will specify the regularization parameter reg_alpha which reduce model complexity and enhance performance, as well as gamma parameter which represents the minimum loss reduction required to make a split and also max_depth used to control over-fitting.

# %%
import scipy.stats as st

params_grid = {  
    'learning_rate': st.uniform(0.01, 0.3),
    'max_depth': list(range(10, 20, 2)),
    'gamma': st.uniform(0, 10),
    'reg_alpha': st.expon(0, 50)}

search_sk = RandomizedSearchCV(skrg, params_grid, cv = 5) # 5 fold cross validation
search_sk.fit(X_train, y_train)

# best parameters
print(search_sk.best_params_); print(search_sk.best_score_)
# Out:
# [11:31:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:39:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:46:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:54:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
# with new parameters
params_new = {
    'booster': 'gbtree', 
    'objective': 'reg:linear', 
    'subsample': 0.8, 
    'colsample_bytree': 0.85, 
    'eta': 0.044338624448041611, 
    'max_depth': 16, 
    'gamma': 0.80198330585415034,
    'reg_alpha': 23.008226565535971,
    'seed': 42} 

model_final = xgb.train(params_new, dtrain, 300, evals = watchlist,
                        early_stopping_rounds = 50, feval = rmspe_xg, verbose_eval = True)
# Out:
# [11:02:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	train-rmse:7.90278	test-rmse:7.90244	train-rmspe:0.999763	test-rmspe:0.999763
# Multiple eval metrics have been passed: 'test-rmspe' will be used for early stopping.
#
# Will train until test-rmspe hasn't improved in 50 rounds.
# [1]	train-rmse:7.55328	test-rmse:7.55286	train-rmspe:0.999592	test-rmspe:0.999592
# [2]	train-rmse:7.21922	test-rmse:7.21887	train-rmspe:0.999363	test-rmspe:0.999363
# [3]	train-rmse:6.89994	test-rmse:6.89968	train-rmspe:0.999059	test-rmspe:0.99906
# [4]	train-rmse:6.59498	test-rmse:6.59467	train-rmspe:0.998664	test-rmspe:0.998665
# [5]	train-rmse:6.30366	test-rmse:6.30324	train-rmspe:0.998155	test-rmspe:0.998156
# [6]	train-rmse:6.02519	test-rmse:6.02485	train-rmspe:0.997509	test-rmspe:0.99751
# [7]	train-rmse:5.75911	test-rmse:5.75876	train-rmspe:0.996699	test-rmspe:0.996701
# [8]	train-rmse:5.50489	test-rmse:5.50453	train-rmspe:0.995697	test-rmspe:0.995698
# [9]	train-rmse:5.26196	test-rmse:5.26157	train-rmspe:0.99447	test-rmspe:0.994472
# [10]	train-rmse:5.02981	test-rmse:5.02946	train-rmspe:0.992985	test-rmspe:0.992988
# [11]	train-rmse:4.80806	test-rmse:4.8077	train-rmspe:0.991207	test-rmspe:0.991209
# [12]	train-rmse:4.59615	test-rmse:4.59577	train-rmspe:0.989098	test-rmspe:0.9891
# [13]	train-rmse:4.39367	test-rmse:4.3933	train-rmspe:0.986623	test-rmspe:0.986625
# [14]	train-rmse:4.20026	test-rmse:4.19991	train-rmspe:0.98374	test-rmspe:0.983742
# [15]	train-rmse:4.01553	test-rmse:4.01514	train-rmspe:0.980416	test-rmspe:0.980418
# [16]	train-rmse:3.83895	test-rmse:3.83857	train-rmspe:0.976612	test-rmspe:0.976612
# [17]	train-rmse:3.67031	test-rmse:3.66992	train-rmspe:0.972293	test-rmspe:0.972292
# [18]	train-rmse:3.50923	test-rmse:3.50881	train-rmspe:0.967431	test-rmspe:0.967426
# [19]	train-rmse:3.35533	test-rmse:3.35491	train-rmspe:0.962002	test-rmspe:0.961994
# [20]	train-rmse:3.20831	test-rmse:3.20787	train-rmspe:0.955973	test-rmspe:0.955959
# [21]	train-rmse:3.06784	test-rmse:3.06745	train-rmspe:0.949351	test-rmspe:0.949333
# [22]	train-rmse:2.9338	test-rmse:2.93334	train-rmspe:0.94208	test-rmspe:0.942055
# [23]	train-rmse:2.80564	test-rmse:2.80523	train-rmspe:0.93418	test-rmspe:0.934147
# [24]	train-rmse:2.68331	test-rmse:2.6829	train-rmspe:0.925628	test-rmspe:0.925582
# [25]	train-rmse:2.56641	test-rmse:2.56599	train-rmspe:0.916456	test-rmspe:0.916398
# [26]	train-rmse:2.45478	test-rmse:2.45434	train-rmspe:0.906646	test-rmspe:0.906569
# [27]	train-rmse:2.34817	test-rmse:2.34776	train-rmspe:0.896194	test-rmspe:0.896092
# [28]	train-rmse:2.24642	test-rmse:2.24603	train-rmspe:0.885126	test-rmspe:0.884998
# [29]	train-rmse:2.14934	test-rmse:2.14894	train-rmspe:0.873449	test-rmspe:0.873285
# [30]	train-rmse:2.05659	test-rmse:2.05618	train-rmspe:0.861234	test-rmspe:0.861027
# [31]	train-rmse:1.96816	test-rmse:1.96771	train-rmspe:0.848452	test-rmspe:0.848193
# [32]	train-rmse:1.88372	test-rmse:1.88324	train-rmspe:0.835186	test-rmspe:0.83487
# [33]	train-rmse:1.803	test-rmse:1.80252	train-rmspe:0.821522	test-rmspe:0.821136
# [34]	train-rmse:1.72605	test-rmse:1.72557	train-rmspe:0.807378	test-rmspe:0.80691
# [35]	train-rmse:1.65268	test-rmse:1.65217	train-rmspe:0.792857	test-rmspe:0.792294
# [36]	train-rmse:1.58248	test-rmse:1.58198	train-rmspe:0.778075	test-rmspe:0.777406
# [37]	train-rmse:1.51571	test-rmse:1.51519	train-rmspe:0.76294	test-rmspe:0.762147
# [38]	train-rmse:1.45194	test-rmse:1.45143	train-rmspe:0.747583	test-rmspe:0.74666
# [39]	train-rmse:1.39036	test-rmse:1.38986	train-rmspe:0.732287	test-rmspe:0.731229
# [40]	train-rmse:1.33212	test-rmse:1.33162	train-rmspe:0.716686	test-rmspe:0.715477
# [41]	train-rmse:1.27668	test-rmse:1.27618	train-rmspe:0.700956	test-rmspe:0.699561
# [42]	train-rmse:1.224	test-rmse:1.2235	train-rmspe:0.685123	test-rmspe:0.683518
# [43]	train-rmse:1.17381	test-rmse:1.17328	train-rmspe:0.669315	test-rmspe:0.667475
# [44]	train-rmse:1.12585	test-rmse:1.12533	train-rmspe:0.653609	test-rmspe:0.651513
# [45]	train-rmse:1.08029	test-rmse:1.07975	train-rmspe:0.637965	test-rmspe:0.635589
# [46]	train-rmse:1.03689	test-rmse:1.03633	train-rmspe:0.622482	test-rmspe:0.619794
# [47]	train-rmse:0.99486	test-rmse:0.994321	train-rmspe:0.60723	test-rmspe:0.604249
# [48]	train-rmse:0.955234	test-rmse:0.954658	train-rmspe:0.59215	test-rmspe:0.588799
# [49]	train-rmse:0.917736	test-rmse:0.917158	train-rmspe:0.577272	test-rmspe:0.573537
# [50]	train-rmse:0.880797	test-rmse:0.880241	train-rmspe:0.562765	test-rmspe:0.558639
# [51]	train-rmse:0.846954	test-rmse:0.846384	train-rmspe:0.54849	test-rmspe:0.543925
# [52]	train-rmse:0.81481	test-rmse:0.814235	train-rmspe:0.534594	test-rmspe:0.52956
# [53]	train-rmse:0.784031	test-rmse:0.783433	train-rmspe:0.521067	test-rmspe:0.515533
# [54]	train-rmse:0.754437	test-rmse:0.753879	train-rmspe:0.507998	test-rmspe:0.501927
# [55]	train-rmse:0.724986	test-rmse:0.72445	train-rmspe:0.495137	test-rmspe:0.488505
# [56]	train-rmse:0.698752	test-rmse:0.698193	train-rmspe:0.482852	test-rmspe:0.475618
# [57]	train-rmse:0.673046	test-rmse:0.67247	train-rmspe:0.47074	test-rmspe:0.462902
# [58]	train-rmse:0.649177	test-rmse:0.648597	train-rmspe:0.459263	test-rmspe:0.450754
# [59]	train-rmse:0.626666	test-rmse:0.626089	train-rmspe:0.448392	test-rmspe:0.439171
# [60]	train-rmse:0.604263	test-rmse:0.60371	train-rmspe:0.437552	test-rmspe:0.427667
# [61]	train-rmse:0.582321	test-rmse:0.581795	train-rmspe:0.426896	test-rmspe:0.416369
# [62]	train-rmse:0.562772	test-rmse:0.562245	train-rmspe:0.417116	test-rmspe:0.405871
# [63]	train-rmse:0.544656	test-rmse:0.544111	train-rmspe:0.408038	test-rmspe:0.396038
# [64]	train-rmse:0.527537	test-rmse:0.526971	train-rmspe:0.399497	test-rmspe:0.386694
# [65]	train-rmse:0.509702	test-rmse:0.509158	train-rmspe:0.390657	test-rmspe:0.377104
# [66]	train-rmse:0.494123	test-rmse:0.493549	train-rmspe:0.382823	test-rmspe:0.368404
# [67]	train-rmse:0.478952	test-rmse:0.47838	train-rmspe:0.375288	test-rmspe:0.360034
# [68]	train-rmse:0.464322	test-rmse:0.463757	train-rmspe:0.368159	test-rmspe:0.351979
# [69]	train-rmse:0.448474	test-rmse:0.447956	train-rmspe:0.360417	test-rmspe:0.343199
# [70]	train-rmse:0.434781	test-rmse:0.434293	train-rmspe:0.353728	test-rmspe:0.335566
# [71]	train-rmse:0.42319	test-rmse:0.422691	train-rmspe:0.348242	test-rmspe:0.329137
# [72]	train-rmse:0.411146	test-rmse:0.410628	train-rmspe:0.342328	test-rmspe:0.322339
# [73]	train-rmse:0.398073	test-rmse:0.397595	train-rmspe:0.335786	test-rmspe:0.314867
# [74]	train-rmse:0.388365	test-rmse:0.387882	train-rmspe:0.331348	test-rmspe:0.309538
# [75]	train-rmse:0.378859	test-rmse:0.37836	train-rmspe:0.326999	test-rmspe:0.304322
# [76]	train-rmse:0.370022	test-rmse:0.369506	train-rmspe:0.323181	test-rmspe:0.299536
# [77]	train-rmse:0.361278	test-rmse:0.360766	train-rmspe:0.31922	test-rmspe:0.294751
# [78]	train-rmse:0.350804	test-rmse:0.350307	train-rmspe:0.313926	test-rmspe:0.288557
# [79]	train-rmse:0.343618	test-rmse:0.343101	train-rmspe:0.311056	test-rmspe:0.284828
# [80]	train-rmse:0.334498	test-rmse:0.334016	train-rmspe:0.306837	test-rmspe:0.279634
# [81]	train-rmse:0.327924	test-rmse:0.327426	train-rmspe:0.304355	test-rmspe:0.276298
# [82]	train-rmse:0.319378	test-rmse:0.318905	train-rmspe:0.300455	test-rmspe:0.271239
# [83]	train-rmse:0.311243	test-rmse:0.310777	train-rmspe:0.296296	test-rmspe:0.266365
# [84]	train-rmse:0.305642	test-rmse:0.305182	train-rmspe:0.294236	test-rmspe:0.263477
# [85]	train-rmse:0.300641	test-rmse:0.300169	train-rmspe:0.292672	test-rmspe:0.261134
# [86]	train-rmse:0.293219	test-rmse:0.292774	train-rmspe:0.288874	test-rmspe:0.256442
# [87]	train-rmse:0.288864	test-rmse:0.288419	train-rmspe:0.287627	test-rmspe:0.254502
# [88]	train-rmse:0.283098	test-rmse:0.282655	train-rmspe:0.285087	test-rmspe:0.251098
# [89]	train-rmse:0.276628	test-rmse:0.276206	train-rmspe:0.282141	test-rmspe:0.247093
# [90]	train-rmse:0.272184	test-rmse:0.271765	train-rmspe:0.280481	test-rmspe:0.244706
# [91]	train-rmse:0.266995	test-rmse:0.266582	train-rmspe:0.277946	test-rmspe:0.241563
# [92]	train-rmse:0.263758	test-rmse:0.263346	train-rmspe:0.277224	test-rmspe:0.240237
# [93]	train-rmse:0.260524	test-rmse:0.260109	train-rmspe:0.276451	test-rmspe:0.238901
# [94]	train-rmse:0.256517	test-rmse:0.256106	train-rmspe:0.274691	test-rmspe:0.236667
# [95]	train-rmse:0.253243	test-rmse:0.25285	train-rmspe:0.273739	test-rmspe:0.235062
# [96]	train-rmse:0.250744	test-rmse:0.250351	train-rmspe:0.273344	test-rmspe:0.234153
# [97]	train-rmse:0.246884	test-rmse:0.24649	train-rmspe:0.271405	test-rmspe:0.23165
# [98]	train-rmse:0.242842	test-rmse:0.242471	train-rmspe:0.269355	test-rmspe:0.229137
# [99]	train-rmse:0.2396	test-rmse:0.239231	train-rmspe:0.268058	test-rmspe:0.227156
# [100]	train-rmse:0.237629	test-rmse:0.237259	train-rmspe:0.267419	test-rmspe:0.226506
# [101]	train-rmse:0.234658	test-rmse:0.234309	train-rmspe:0.2663	test-rmspe:0.224787
# [102]	train-rmse:0.231287	test-rmse:0.230942	train-rmspe:0.264431	test-rmspe:0.222556
# [103]	train-rmse:0.229311	test-rmse:0.228977	train-rmspe:0.263983	test-rmspe:0.221714
# [104]	train-rmse:0.227506	test-rmse:0.227193	train-rmspe:0.263654	test-rmspe:0.221042
# [105]	train-rmse:0.226074	test-rmse:0.225766	train-rmspe:0.263671	test-rmspe:0.220692
# [106]	train-rmse:0.222938	test-rmse:0.22265	train-rmspe:0.262233	test-rmspe:0.218599
# [107]	train-rmse:0.221044	test-rmse:0.22076	train-rmspe:0.261839	test-rmspe:0.217567
# [108]	train-rmse:0.218343	test-rmse:0.218075	train-rmspe:0.260812	test-rmspe:0.215748
# [109]	train-rmse:0.216342	test-rmse:0.216068	train-rmspe:0.260202	test-rmspe:0.214616
# [110]	train-rmse:0.215315	test-rmse:0.215051	train-rmspe:0.26037	test-rmspe:0.214439
# [111]	train-rmse:0.21309	test-rmse:0.212841	train-rmspe:0.259423	test-rmspe:0.21303
# [112]	train-rmse:0.211354	test-rmse:0.211114	train-rmspe:0.258787	test-rmspe:0.212048
# [113]	train-rmse:0.209973	test-rmse:0.20974	train-rmspe:0.258457	test-rmspe:0.211417
# [114]	train-rmse:0.208992	test-rmse:0.208774	train-rmspe:0.258341	test-rmspe:0.21111
# [115]	train-rmse:0.20701	test-rmse:0.206789	train-rmspe:0.257247	test-rmspe:0.209654
# [116]	train-rmse:0.206304	test-rmse:0.206079	train-rmspe:0.25725	test-rmspe:0.209598
# [117]	train-rmse:0.204211	test-rmse:0.203987	train-rmspe:0.255929	test-rmspe:0.207978
# [118]	train-rmse:0.20299	test-rmse:0.202774	train-rmspe:0.255378	test-rmspe:0.207287
# [119]	train-rmse:0.202017	test-rmse:0.201814	train-rmspe:0.255037	test-rmspe:0.206839
# [120]	train-rmse:0.199499	test-rmse:0.199306	train-rmspe:0.253635	test-rmspe:0.204826
# [121]	train-rmse:0.19746	test-rmse:0.197282	train-rmspe:0.25221	test-rmspe:0.203178
# [122]	train-rmse:0.196659	test-rmse:0.196484	train-rmspe:0.252145	test-rmspe:0.202877
# [123]	train-rmse:0.196036	test-rmse:0.195866	train-rmspe:0.252118	test-rmspe:0.202683
# [124]	train-rmse:0.195475	test-rmse:0.195309	train-rmspe:0.252126	test-rmspe:0.202558
# [125]	train-rmse:0.194423	test-rmse:0.194259	train-rmspe:0.251667	test-rmspe:0.201915
# [126]	train-rmse:0.193265	test-rmse:0.193105	train-rmspe:0.251265	test-rmspe:0.201149
# [127]	train-rmse:0.191252	test-rmse:0.191102	train-rmspe:0.250146	test-rmspe:0.199474
# [128]	train-rmse:0.190844	test-rmse:0.190701	train-rmspe:0.250277	test-rmspe:0.199424
# [129]	train-rmse:0.188606	test-rmse:0.188484	train-rmspe:0.248913	test-rmspe:0.197487
# [130]	train-rmse:0.188204	test-rmse:0.18809	train-rmspe:0.248925	test-rmspe:0.197414
# [131]	train-rmse:0.186928	test-rmse:0.186811	train-rmspe:0.248313	test-rmspe:0.196437
# [132]	train-rmse:0.1862	test-rmse:0.186097	train-rmspe:0.247746	test-rmspe:0.195966
# [133]	train-rmse:0.185514	test-rmse:0.185405	train-rmspe:0.24752	test-rmspe:0.195503
# [134]	train-rmse:0.184668	test-rmse:0.184565	train-rmspe:0.247205	test-rmspe:0.194919
# [135]	train-rmse:0.182664	test-rmse:0.182582	train-rmspe:0.246075	test-rmspe:0.193173
# [136]	train-rmse:0.182294	test-rmse:0.182217	train-rmspe:0.246036	test-rmspe:0.193057
# [137]	train-rmse:0.181342	test-rmse:0.181266	train-rmspe:0.245393	test-rmspe:0.192266
# [138]	train-rmse:0.180822	test-rmse:0.180752	train-rmspe:0.245186	test-rmspe:0.19198
# [139]	train-rmse:0.180409	test-rmse:0.180342	train-rmspe:0.245133	test-rmspe:0.191773
# [140]	train-rmse:0.179411	test-rmse:0.179349	train-rmspe:0.244573	test-rmspe:0.190985
# [141]	train-rmse:0.179031	test-rmse:0.178971	train-rmspe:0.244443	test-rmspe:0.190784
# [142]	train-rmse:0.178615	test-rmse:0.178568	train-rmspe:0.244202	test-rmspe:0.190533
# [143]	train-rmse:0.17814	test-rmse:0.178092	train-rmspe:0.244039	test-rmspe:0.190198
# [144]	train-rmse:0.177726	test-rmse:0.177686	train-rmspe:0.243828	test-rmspe:0.189942
# [145]	train-rmse:0.177163	test-rmse:0.177139	train-rmspe:0.243599	test-rmspe:0.189557
# [146]	train-rmse:0.176123	test-rmse:0.176102	train-rmspe:0.242977	test-rmspe:0.18861
# [147]	train-rmse:0.174527	test-rmse:0.174503	train-rmspe:0.24196	test-rmspe:0.187094
# [148]	train-rmse:0.173832	test-rmse:0.173811	train-rmspe:0.24161	test-rmspe:0.186562
# [149]	train-rmse:0.173548	test-rmse:0.17354	train-rmspe:0.241467	test-rmspe:0.186372
# [150]	train-rmse:0.173195	test-rmse:0.173197	train-rmspe:0.241287	test-rmspe:0.186162
# [151]	train-rmse:0.172373	test-rmse:0.172381	train-rmspe:0.24052	test-rmspe:0.185388
# [152]	train-rmse:0.171818	test-rmse:0.171839	train-rmspe:0.2401	test-rmspe:0.184923
# [153]	train-rmse:0.17096	test-rmse:0.170985	train-rmspe:0.239524	test-rmspe:0.184131
# [154]	train-rmse:0.170171	test-rmse:0.170198	train-rmspe:0.239018	test-rmspe:0.183409
# [155]	train-rmse:0.168866	test-rmse:0.168911	train-rmspe:0.23809	test-rmspe:0.182198
# [156]	train-rmse:0.168663	test-rmse:0.168714	train-rmspe:0.237992	test-rmspe:0.182085
# [157]	train-rmse:0.168429	test-rmse:0.168486	train-rmspe:0.237829	test-rmspe:0.181944
# [158]	train-rmse:0.167739	test-rmse:0.167803	train-rmspe:0.2374	test-rmspe:0.181361
# [159]	train-rmse:0.166738	test-rmse:0.166813	train-rmspe:0.236765	test-rmspe:0.18044
# [160]	train-rmse:0.165872	test-rmse:0.165944	train-rmspe:0.236277	test-rmspe:0.179608
# [161]	train-rmse:0.165228	test-rmse:0.165307	train-rmspe:0.235867	test-rmspe:0.179043
# [162]	train-rmse:0.164266	test-rmse:0.164349	train-rmspe:0.235261	test-rmspe:0.178124
# [163]	train-rmse:0.163864	test-rmse:0.163943	train-rmspe:0.234954	test-rmspe:0.177756
# [164]	train-rmse:0.163688	test-rmse:0.163769	train-rmspe:0.234887	test-rmspe:0.177672
# [165]	train-rmse:0.163383	test-rmse:0.163466	train-rmspe:0.234698	test-rmspe:0.177411
# [166]	train-rmse:0.162756	test-rmse:0.162844	train-rmspe:0.234169	test-rmspe:0.176789
# [167]	train-rmse:0.161931	test-rmse:0.16203	train-rmspe:0.233574	test-rmspe:0.176025
# [168]	train-rmse:0.161715	test-rmse:0.161813	train-rmspe:0.233528	test-rmspe:0.175845
# [169]	train-rmse:0.161005	test-rmse:0.161099	train-rmspe:0.233052	test-rmspe:0.175121
# [170]	train-rmse:0.160577	test-rmse:0.160684	train-rmspe:0.232765	test-rmspe:0.174738
# [171]	train-rmse:0.16	test-rmse:0.160102	train-rmspe:0.232514	test-rmspe:0.174183
# [172]	train-rmse:0.15968	test-rmse:0.159785	train-rmspe:0.232429	test-rmspe:0.173894
# [173]	train-rmse:0.159032	test-rmse:0.159144	train-rmspe:0.231935	test-rmspe:0.173257
# [174]	train-rmse:0.158646	test-rmse:0.158761	train-rmspe:0.231633	test-rmspe:0.172874
# [175]	train-rmse:0.157969	test-rmse:0.15809	train-rmspe:0.231085	test-rmspe:0.172185
# [176]	train-rmse:0.157734	test-rmse:0.15786	train-rmspe:0.230942	test-rmspe:0.171984
# [177]	train-rmse:0.157068	test-rmse:0.1572	train-rmspe:0.230448	test-rmspe:0.171308
# [178]	train-rmse:0.156904	test-rmse:0.157042	train-rmspe:0.230271	test-rmspe:0.171176
# [179]	train-rmse:0.15664	test-rmse:0.156779	train-rmspe:0.230242	test-rmspe:0.170933
# [180]	train-rmse:0.155991	test-rmse:0.156141	train-rmspe:0.230096	test-rmspe:0.170289
# [181]	train-rmse:0.154967	test-rmse:0.155121	train-rmspe:0.22933	test-rmspe:0.169245
# [182]	train-rmse:0.154772	test-rmse:0.15493	train-rmspe:0.229163	test-rmspe:0.169086
# [183]	train-rmse:0.154644	test-rmse:0.154803	train-rmspe:0.229081	test-rmspe:0.16898
# [184]	train-rmse:0.15445	test-rmse:0.154608	train-rmspe:0.229027	test-rmspe:0.168809
# [185]	train-rmse:0.15405	test-rmse:0.154209	train-rmspe:0.228912	test-rmspe:0.168405
# [186]	train-rmse:0.153718	test-rmse:0.153878	train-rmspe:0.228692	test-rmspe:0.168107
# [187]	train-rmse:0.153352	test-rmse:0.153516	train-rmspe:0.228516	test-rmspe:0.167767
# [188]	train-rmse:0.153036	test-rmse:0.153204	train-rmspe:0.2283	test-rmspe:0.167437
# [189]	train-rmse:0.15279	test-rmse:0.152962	train-rmspe:0.228145	test-rmspe:0.16722
# [190]	train-rmse:0.152458	test-rmse:0.15263	train-rmspe:0.227973	test-rmspe:0.166899
# [191]	train-rmse:0.152227	test-rmse:0.152399	train-rmspe:0.227972	test-rmspe:0.166669
# [192]	train-rmse:0.151866	test-rmse:0.152046	train-rmspe:0.227843	test-rmspe:0.166325
# [193]	train-rmse:0.151726	test-rmse:0.151914	train-rmspe:0.227745	test-rmspe:0.166222
# [194]	train-rmse:0.151548	test-rmse:0.151735	train-rmspe:0.227687	test-rmspe:0.166052
# [195]	train-rmse:0.151264	test-rmse:0.151457	train-rmspe:0.227334	test-rmspe:0.165764
# [196]	train-rmse:0.150824	test-rmse:0.151018	train-rmspe:0.227009	test-rmspe:0.165307
# [197]	train-rmse:0.150638	test-rmse:0.150833	train-rmspe:0.226892	test-rmspe:0.165106
# [198]	train-rmse:0.150508	test-rmse:0.150701	train-rmspe:0.226802	test-rmspe:0.164983
# [199]	train-rmse:0.149849	test-rmse:0.150043	train-rmspe:0.226217	test-rmspe:0.164296
# [200]	train-rmse:0.149237	test-rmse:0.149432	train-rmspe:0.225788	test-rmspe:0.163693
# [201]	train-rmse:0.149097	test-rmse:0.149296	train-rmspe:0.225708	test-rmspe:0.163571
# [202]	train-rmse:0.148949	test-rmse:0.149147	train-rmspe:0.225568	test-rmspe:0.163414
# [203]	train-rmse:0.148578	test-rmse:0.148791	train-rmspe:0.225291	test-rmspe:0.163062
# [204]	train-rmse:0.147868	test-rmse:0.14808	train-rmspe:0.224752	test-rmspe:0.162329
# [205]	train-rmse:0.147728	test-rmse:0.147943	train-rmspe:0.224668	test-rmspe:0.162199
# [206]	train-rmse:0.147657	test-rmse:0.147872	train-rmspe:0.224616	test-rmspe:0.162132
# [207]	train-rmse:0.147205	test-rmse:0.147419	train-rmspe:0.22412	test-rmspe:0.16164
# [208]	train-rmse:0.147023	test-rmse:0.14724	train-rmspe:0.224218	test-rmspe:0.161457
# [209]	train-rmse:0.146902	test-rmse:0.14712	train-rmspe:0.224356	test-rmspe:0.161329
# [210]	train-rmse:0.146468	test-rmse:0.14669	train-rmspe:0.224121	test-rmspe:0.160867
# [211]	train-rmse:0.145882	test-rmse:0.146105	train-rmspe:0.223555	test-rmspe:0.160271
# [212]	train-rmse:0.145802	test-rmse:0.146028	train-rmspe:0.223428	test-rmspe:0.160209
# [213]	train-rmse:0.145715	test-rmse:0.145942	train-rmspe:0.223384	test-rmspe:0.160122
# [214]	train-rmse:0.145547	test-rmse:0.145779	train-rmspe:0.2233	test-rmspe:0.15994
# [215]	train-rmse:0.145432	test-rmse:0.145667	train-rmspe:0.223218	test-rmspe:0.159846
# [216]	train-rmse:0.145294	test-rmse:0.145534	train-rmspe:0.223137	test-rmspe:0.159721
# [217]	train-rmse:0.144922	test-rmse:0.145167	train-rmspe:0.222842	test-rmspe:0.159333
# [218]	train-rmse:0.144496	test-rmse:0.144743	train-rmspe:0.222639	test-rmspe:0.158904
# [219]	train-rmse:0.144412	test-rmse:0.144658	train-rmspe:0.222628	test-rmspe:0.15882
# [220]	train-rmse:0.14413	test-rmse:0.144373	train-rmspe:0.222422	test-rmspe:0.158523
# [221]	train-rmse:0.144013	test-rmse:0.144254	train-rmspe:0.22234	test-rmspe:0.158397
# [222]	train-rmse:0.14374	test-rmse:0.143982	train-rmspe:0.222216	test-rmspe:0.158098
# [223]	train-rmse:0.143556	test-rmse:0.143799	train-rmspe:0.222163	test-rmspe:0.157906
# [224]	train-rmse:0.143388	test-rmse:0.143633	train-rmspe:0.221986	test-rmspe:0.157744
# [225]	train-rmse:0.143185	test-rmse:0.143428	train-rmspe:0.221828	test-rmspe:0.157526
# [226]	train-rmse:0.142872	test-rmse:0.143119	train-rmspe:0.221678	test-rmspe:0.157226
# [227]	train-rmse:0.142599	test-rmse:0.142844	train-rmspe:0.221572	test-rmspe:0.156954
# [228]	train-rmse:0.142317	test-rmse:0.142567	train-rmspe:0.221317	test-rmspe:0.156667
# [229]	train-rmse:0.142215	test-rmse:0.142462	train-rmspe:0.221197	test-rmspe:0.156551
# [230]	train-rmse:0.142003	test-rmse:0.142248	train-rmspe:0.221039	test-rmspe:0.156328
# [231]	train-rmse:0.141728	test-rmse:0.14197	train-rmspe:0.220874	test-rmspe:0.15603
# [232]	train-rmse:0.141547	test-rmse:0.141789	train-rmspe:0.220731	test-rmspe:0.155839
# [233]	train-rmse:0.141435	test-rmse:0.141678	train-rmspe:0.220605	test-rmspe:0.155738
# [234]	train-rmse:0.141372	test-rmse:0.141613	train-rmspe:0.220553	test-rmspe:0.155674
# [235]	train-rmse:0.140848	test-rmse:0.141091	train-rmspe:0.220195	test-rmspe:0.155144
# [236]	train-rmse:0.140628	test-rmse:0.140875	train-rmspe:0.220027	test-rmspe:0.15493
# [237]	train-rmse:0.14051	test-rmse:0.140758	train-rmspe:0.220036	test-rmspe:0.154814
# [238]	train-rmse:0.140396	test-rmse:0.140644	train-rmspe:0.219965	test-rmspe:0.154683
# [239]	train-rmse:0.140188	test-rmse:0.140439	train-rmspe:0.219795	test-rmspe:0.154462
# [240]	train-rmse:0.139855	test-rmse:0.140103	train-rmspe:0.219554	test-rmspe:0.154103
# [241]	train-rmse:0.139694	test-rmse:0.13994	train-rmspe:0.219641	test-rmspe:0.153939
# [242]	train-rmse:0.139463	test-rmse:0.139707	train-rmspe:0.219533	test-rmspe:0.153707
# [243]	train-rmse:0.139382	test-rmse:0.139627	train-rmspe:0.219481	test-rmspe:0.15363
# [244]	train-rmse:0.139194	test-rmse:0.139437	train-rmspe:0.219345	test-rmspe:0.15344
# [245]	train-rmse:0.138996	test-rmse:0.139238	train-rmspe:0.219204	test-rmspe:0.153236
# [246]	train-rmse:0.138886	test-rmse:0.13913	train-rmspe:0.219128	test-rmspe:0.153126
# [247]	train-rmse:0.138722	test-rmse:0.138965	train-rmspe:0.219023	test-rmspe:0.152938
# [248]	train-rmse:0.138647	test-rmse:0.138892	train-rmspe:0.21891	test-rmspe:0.152872
# [249]	train-rmse:0.138573	test-rmse:0.138819	train-rmspe:0.218855	test-rmspe:0.152805
# [250]	train-rmse:0.138363	test-rmse:0.138608	train-rmspe:0.218703	test-rmspe:0.15259
# [251]	train-rmse:0.138311	test-rmse:0.138558	train-rmspe:0.218651	test-rmspe:0.152532
# [252]	train-rmse:0.13823	test-rmse:0.13848	train-rmspe:0.218715	test-rmspe:0.15244
# [253]	train-rmse:0.138014	test-rmse:0.138263	train-rmspe:0.218584	test-rmspe:0.152201
# [254]	train-rmse:0.137832	test-rmse:0.13808	train-rmspe:0.218338	test-rmspe:0.152003
# [255]	train-rmse:0.137774	test-rmse:0.138023	train-rmspe:0.218308	test-rmspe:0.151949
# [256]	train-rmse:0.137512	test-rmse:0.137768	train-rmspe:0.218165	test-rmspe:0.15166
# [257]	train-rmse:0.137381	test-rmse:0.137638	train-rmspe:0.218044	test-rmspe:0.151505
# [258]	train-rmse:0.137308	test-rmse:0.137567	train-rmspe:0.218078	test-rmspe:0.151418
# [259]	train-rmse:0.137013	test-rmse:0.13727	train-rmspe:0.217891	test-rmspe:0.151112
# [260]	train-rmse:0.136863	test-rmse:0.137122	train-rmspe:0.217792	test-rmspe:0.150971
# [261]	train-rmse:0.136449	test-rmse:0.136708	train-rmspe:0.217421	test-rmspe:0.150532
# [262]	train-rmse:0.136113	test-rmse:0.136368	train-rmspe:0.217175	test-rmspe:0.150169
# [263]	train-rmse:0.136037	test-rmse:0.136292	train-rmspe:0.217129	test-rmspe:0.150097
# [264]	train-rmse:0.1359	test-rmse:0.136158	train-rmspe:0.217221	test-rmspe:0.149956
# [265]	train-rmse:0.135868	test-rmse:0.136127	train-rmspe:0.217199	test-rmspe:0.149936
# [266]	train-rmse:0.135642	test-rmse:0.135899	train-rmspe:0.217045	test-rmspe:0.149705
# [267]	train-rmse:0.135557	test-rmse:0.135814	train-rmspe:0.216932	test-rmspe:0.149599
# [268]	train-rmse:0.135504	test-rmse:0.135764	train-rmspe:0.216864	test-rmspe:0.149547
# [269]	train-rmse:0.135352	test-rmse:0.135613	train-rmspe:0.216751	test-rmspe:0.14939
# [270]	train-rmse:0.135019	test-rmse:0.135278	train-rmspe:0.216476	test-rmspe:0.149041
# [271]	train-rmse:0.134878	test-rmse:0.135136	train-rmspe:0.216572	test-rmspe:0.148889
# [272]	train-rmse:0.13484	test-rmse:0.135101	train-rmspe:0.216538	test-rmspe:0.148852
# [273]	train-rmse:0.134721	test-rmse:0.134982	train-rmspe:0.216405	test-rmspe:0.148724
# [274]	train-rmse:0.134459	test-rmse:0.134717	train-rmspe:0.216189	test-rmspe:0.14845
# [275]	train-rmse:0.134416	test-rmse:0.134676	train-rmspe:0.216192	test-rmspe:0.148414
# [276]	train-rmse:0.13437	test-rmse:0.134631	train-rmspe:0.216149	test-rmspe:0.148365
# [277]	train-rmse:0.134111	test-rmse:0.134367	train-rmspe:0.215963	test-rmspe:0.148082
# [278]	train-rmse:0.134063	test-rmse:0.134319	train-rmspe:0.215973	test-rmspe:0.148026
# [279]	train-rmse:0.133968	test-rmse:0.134225	train-rmspe:0.215882	test-rmspe:0.147875
# [280]	train-rmse:0.133741	test-rmse:0.133993	train-rmspe:0.215739	test-rmspe:0.147639
# [281]	train-rmse:0.133617	test-rmse:0.133868	train-rmspe:0.215627	test-rmspe:0.147496
# [282]	train-rmse:0.133554	test-rmse:0.133808	train-rmspe:0.215555	test-rmspe:0.147428
# [283]	train-rmse:0.133483	test-rmse:0.133739	train-rmspe:0.215497	test-rmspe:0.147345
# [284]	train-rmse:0.133229	test-rmse:0.133485	train-rmspe:0.21532	test-rmspe:0.147078
# [285]	train-rmse:0.133146	test-rmse:0.133404	train-rmspe:0.215209	test-rmspe:0.14699
# [286]	train-rmse:0.132953	test-rmse:0.13321	train-rmspe:0.215071	test-rmspe:0.146788
# [287]	train-rmse:0.132863	test-rmse:0.133122	train-rmspe:0.215014	test-rmspe:0.146689
# [288]	train-rmse:0.132791	test-rmse:0.133053	train-rmspe:0.21486	test-rmspe:0.146588
# [289]	train-rmse:0.132634	test-rmse:0.132896	train-rmspe:0.214788	test-rmspe:0.146424
# [290]	train-rmse:0.132429	test-rmse:0.132694	train-rmspe:0.214589	test-rmspe:0.146201
# [291]	train-rmse:0.13236	test-rmse:0.132626	train-rmspe:0.214557	test-rmspe:0.146131
# [292]	train-rmse:0.132279	test-rmse:0.132544	train-rmspe:0.214502	test-rmspe:0.146041
# [293]	train-rmse:0.13225	test-rmse:0.132515	train-rmspe:0.214495	test-rmspe:0.146016
# [294]	train-rmse:0.132188	test-rmse:0.132455	train-rmspe:0.214484	test-rmspe:0.145959
# [295]	train-rmse:0.132044	test-rmse:0.132308	train-rmspe:0.214311	test-rmspe:0.145794
# [296]	train-rmse:0.131913	test-rmse:0.132178	train-rmspe:0.214226	test-rmspe:0.145668
# [297]	train-rmse:0.131855	test-rmse:0.132119	train-rmspe:0.214158	test-rmspe:0.14561
# [298]	train-rmse:0.131716	test-rmse:0.13198	train-rmspe:0.214064	test-rmspe:0.145461
# [299]	train-rmse:0.131506	test-rmse:0.131774	train-rmspe:0.213942	test-rmspe:0.145249

# %% [markdown]
# Last five rows:
#
# [295] train-rmspe:0.214311	test-rmspe:0.145794
#
# [296]	train-rmspe:0.214226	test-rmspe:0.145668
#
# [297]	train-rmspe:0.214158	test-rmspe:0.14561
#
# [298]	train-rmspe:0.214064	test-rmspe:0.145461
#
# [299]	train-rmspe:0.213942	test-rmspe:0.145249
#
# We resolved an issue with overfitting, but due to the decrease of learning rate (eta) we got a bit worse overall score on the test set (0.11 to 0.14).

# %%
yhat = model_final.predict(xgb.DMatrix(X_test[predictors]))
error = rmspe(X_test.Sales.values, np.exp(yhat))

print('First validation yelds RMSPE: {:.6f}'.format(error))
# Out:
# First validation yelds RMSPE: 0.145202

# %% [markdown]
# First validation yelds RMSPE: 0.146761
# Even though we observed a bit higher RMSPE value, we need to remember that the corresponding eta for the first version was 0.1, which is usually considered as high. I think that it's remarkable that we got more or less the same result but with 2x lower eta (0.1 to 0.04).
#
# Next steps towards model's improvement will involve further decrease of eta, tuning of correpsonding gamma and max_depth.
#
# Model understanding
# Feature importance scores help us see which variables contributed the most to the score.

# %%
xgb.plot_importance(model_final)

# %% [markdown]
# Variables Store and CompetitionDistance are both leading. Then go features CompetitionOpenSinceMonth, CompetitionOpenSinceYear, DayOfWeek, PromoSinceWeek and deducted features PromoOpen.

# %% [markdown]
# Prediction to unseen data

# %%
# predictions to unseen data
unseen = xgb.DMatrix(test_store[predictors])
test_p = model_final.predict(unseen)

forecasts = pd.DataFrame({'Id': test['Id'], 
                          'Sales': np.exp(test_p)})
# forecasts
forecasts.head()
# Out:
#             Id        Sales
# Date
# 2015-09-17   1  4402.751953
# 2015-09-17   2  4531.572266
# 2015-09-17   3  4772.706543
# 2015-09-17   4  5394.405762
# 2015-09-17   5  5431.019531
